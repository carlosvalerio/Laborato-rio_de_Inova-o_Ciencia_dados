# %% [markdown]
# #**DATASETS**

# %% [markdown]
# Link para download dos arquivos ('https://drive.google.com/drive/folders/14TcAxrrtD0WOuG-pAkCVeE-17aouxiB6?usp=sharing)

# %% [markdown]
# **Importação das bibliotecas**

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import pandas as pd

# %% [markdown]
# #**STJ**

# %% [markdown]
# **Seleção de Dados**

# %%
STJ_cn = '/content/STJ_CN.csv'
STJ_cpl = '/content/STJ_CPL.csv'
STJ_cpl15 = '/content/STJ_CPL_15anos.csv'
STJ_julg = '/content/STJ_Sent.csv'
STJ_baix = '/content/STJ_TBaix.csv'

STJ_cn = pd.read_csv(STJ_cn, encoding='"latin-1"', sep=';', on_bad_lines='skip')
STJ_cpl = pd.read_csv(STJ_cpl, encoding='latin-1', sep=';', on_bad_lines='skip')
STJ_cpl15 = pd.read_csv(STJ_cpl15, encoding='latin-1', sep=';', on_bad_lines='skip')
STJ_julg = pd.read_csv(STJ_julg, encoding='latin-1', sep=';', on_bad_lines='skip')
STJ_baix = pd.read_csv(STJ_baix, encoding='latin-1', sep=';', on_bad_lines='skip')

# %%
STJ_cn = STJ_cn.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Codigos_classes', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

STJ_cn = STJ_cn.dropna()

df_STJ1 = STJ_cn.sample(n=1000, random_state=42).copy()
df_STJ1['Status'] = 'Novo'

df_STJ1.head(5)
# Out:
#        Tribunal Grau                             Nome_Orgao     Ano   Mes  \
# 23433       STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   5.0
# 425076      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024.0  11.0
# 323060      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   9.0
# 81945       STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0  11.0
# 83055       STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   1.0
#
#                          Processo  Codigo_da_Ultima_classe  \
# 23433   5009921-50.2020.4.03.6183                   1032.0
# 425076  0414234-25.2024.3.00.0000                   1720.0
# 323060        sigiloso(709521197)                  11881.0
# 81945   0802709-59.2023.8.12.0001                  11881.0
# 83055   5006641-38.2016.8.13.0480                  11881.0
#
#              Nome_da_Ultima_classe Codigos_assuntos Data_de_Referencia  \
# 23433             RECURSO ESPECIAL      {6176,6182}         2024-05-10
# 425076               HABEAS CORPUS      {5566,3546}         2024-11-04
# 323060  AGRAVO EM RECURSO ESPECIAL           {3465}         2024-09-17
# 81945   AGRAVO EM RECURSO ESPECIAL           {9607}         2024-11-11
# 83055   AGRAVO EM RECURSO ESPECIAL    {10504,10638}         2024-01-22
#
#             Formato  Codigo_Orgao Status
# 23433   EletrÃ´nico       12728.0   Novo
# 425076  EletrÃ´nico       76776.0   Novo
# 323060  EletrÃ´nico       12728.0   Novo
# 81945   EletrÃ´nico       12728.0   Novo
# 83055   EletrÃ´nico       12728.0   Novo

# %%
STJ_cpl = STJ_cpl.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Codigos_classes', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

STJ_cpl = STJ_cpl.dropna()

df_STJ2 = STJ_cpl.sample(n=1000, random_state=42).copy()
df_STJ2['Status'] = 'Pendente'

df_STJ2.head(5)
# Out:
#        Tribunal Grau                                         Nome_Orgao   Ano  \
# 330944      STJ  SUP                      SUPERIOR TRIBUNAL DE JUSTIÃA  2025
# 88932       STJ  SUP     GABINETE DO MINISTRO ANTONIO SALDANHA PALHEIRO  2025
# 6080        STJ  SUP               GABINETE DO MINISTRO AFRÃNIO VILELA  2025
# 115445      STJ  SUP  GABINETE DA MINISTRA MARIA THEREZA DE ASSIS MOURA  2025
# 85516       STJ  SUP  GABINETE DO DESEMBARGADOR CONVOCADO OTÃ?VIO DE...  2025
#
#         Mes                   Processo  Codigo_da_Ultima_classe  \
# 330944    1  1007608-19.2018.8.11.0002                    11881
# 88932     1  0014618-60.2018.8.16.0013                    11881
# 6080      1  0009486-44.2017.8.07.0001                     1032
# 115445    1  0012176-73.2010.4.03.6100                    11881
# 85516     1  1522952-45.2020.8.26.0050                    11881
#
#              Nome_da_Ultima_classe                 Codigos_assuntos  \
# 330944  AGRAVO EM RECURSO ESPECIAL               {10433,10439,9047}
# 88932   AGRAVO EM RECURSO ESPECIAL                      {3417,3431}
# 6080              RECURSO ESPECIAL                          {10375}
# 115445  AGRAVO EM RECURSO ESPECIAL  {6064,5994,5987,6060,6068,6062}
# 85516   AGRAVO EM RECURSO ESPECIAL                           {3608}
#
#        Data_de_inicio Data_da_ultima_movimentacao  Dias_de_antiguidade  \
# 330944     2024-12-19                  2025-01-28                  7.0
# 88932      2023-11-24                  2025-01-31                434.0
# 6080       2018-11-29                  2025-02-03               2254.0
# 115445     2024-03-08                  2024-08-26                319.0
# 85516      2023-11-08                  2024-11-25                450.0
#
#             Formato  Codigo_Orgao    Status
# 330944  EletrÃ´nico         12728  Pendente
# 88932   EletrÃ´nico         76748  Pendente
# 6080    EletrÃ´nico         87913  Pendente
# 115445  EletrÃ´nico         76764  Pendente
# 85516   EletrÃ´nico         88421  Pendente

# %%
STJ_cpl15 = STJ_cpl15.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Codigos_classes', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STJ3 = STJ_cpl15.copy()
df_STJ3['Status'] = 'Pendente +15'

df_STJ3.head(5)
# Out:
#   Tribunal Grau                                       Nome_Orgao   Ano  Mes  \
# 0      STJ  SUP  GABINETE DO MINISTRO ANTÃNIO DE PÃ?DUA RIBEIRO  2025    1
# 1      STJ  SUP             GABINETE DO MINISTRO HÃLIO MOSIMANN  2025    1
# 2      STJ  SUP                   PRESIDENTE DA PRIMEIRA SEÃÃO  2025    1
# 3      STJ  SUP                   PRESIDENTE DA PRIMEIRA SEÃÃO  2025    1
# 4      STJ  SUP                    SUPERIOR TRIBUNAL DE JUSTIÃA  2025    1
#
#                     Processo  Codigo_da_Ultima_classe  Nome_da_Ultima_classe  \
# 0  0011625-92.1991.3.00.0000                     1029  MANDADO DE SEGURANÃA
# 1  0000003-79.1992.3.00.0000                     1029  MANDADO DE SEGURANÃA
# 2  0014173-22.1993.3.00.0000                     1029  MANDADO DE SEGURANÃA
# 3  0022333-02.1994.3.00.0000                     1029  MANDADO DE SEGURANÃA
# 4  0024524-20.1994.3.00.0000                     1029  MANDADO DE SEGURANÃA
#
#   Codigos_assuntos Data_de_inicio Data_da_ultima_movimentacao  \
# 0           {9997}     1991-06-26                  2020-09-09
# 1          {10097}     1992-01-02                  2022-11-29
# 2          {10098}     2011-08-10                  2024-09-10
# 3          {10098}     2011-08-10                  2024-09-20
# 4          {10098}     2017-11-21                  2025-01-14
#
#    Dias_de_antiguidade      Formato  Codigo_Orgao        Status
# 0                12273  EletrÃ´nico         82881  Pendente +15
# 1                12083  EletrÃ´nico         82844  Pendente +15
# 2                11567  EletrÃ´nico         76780  Pendente +15
# 3                11179  EletrÃ´nico         76780  Pendente +15
# 4                11158  EletrÃ´nico         12728  Pendente +15

# %%
STJ_julg = STJ_julg.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Codigos_classes', 'Data_da_decisao:_Situacao:_Movimento', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

STJ_julg = STJ_julg.dropna()

df_STJ4 = STJ_julg.sample(n=1000, random_state=42).copy()
df_STJ4['Status'] = 'Julgado'

df_STJ4.head(5)
# Out:
#        Tribunal Grau                                         Nome_Orgao   Ano  \
# 187775      STJ  SUP       GABINETE DO MINISTRO ANTONIO CARLOS FERREIRA  2024
# 331358      STJ  SUP                   GABINETE DO MINISTRO MARCO BUZZI  2024
# 197734      STJ  SUP     GABINETE DO MINISTRO ANTONIO SALDANHA PALHEIRO  2024
# 327875      STJ  SUP                   GABINETE DO MINISTRO MARCO BUZZI  2024
# 265208      STJ  SUP  GABINETE DO MINISTRO HUMBERTO EUSTÃ?QUIO SOARE...  2024
#
#         Mes                   Processo  Codigo_da_Ultima_classe  \
# 187775    8  5134553-83.2023.8.21.7000                    11881
# 331358    9  0329678-90.2024.3.00.0000                     1054
# 197734   11  0038808-84.2008.8.24.0023                    11881
# 327875    9  5004025-10.2021.8.21.0087                    11881
# 265208    6  0291501-16.2010.8.21.0010                    11881
#
#              Nome_da_Ultima_classe Codigos_assuntos Data_de_Referencia  \
# 187775  AGRAVO EM RECURSO ESPECIAL           {7752}         2024-08-23
# 331358    CONFLITO DE COMPETÃNCIA           {4993}         2024-09-07
# 197734  AGRAVO EM RECURSO ESPECIAL           {3608}         2024-11-05
# 327875  AGRAVO EM RECURSO ESPECIAL     {11974,7770}         2024-09-26
# 265208  AGRAVO EM RECURSO ESPECIAL           {9584}         2024-06-06
#
#             Formato  Codigo_Orgao   Status
# 187775  EletrÃ´nico       76747.0  Julgado
# 331358  EletrÃ´nico       76762.0  Julgado
# 197734  EletrÃ´nico       76748.0  Julgado
# 327875  EletrÃ´nico       76762.0  Julgado
# 265208  EletrÃ´nico       76755.0  Julgado

# %%
STJ_baix =STJ_baix.drop(columns=['UF', 'Recurso_Originario', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Codigos_Classes', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

STJ_baix = STJ_baix.dropna()

df_STJ5 = STJ_baix.sample(n=600, random_state=42).copy()
df_STJ5['Status'] = 'Baixado'

df_STJ5.head(5)
# Out:
#        Tribunal Grau                                       Nome_orgao   Ano  \
# 449690      STJ  SUP            GABINETE DA MINISTRA DANIELA TEIXEIRA  2024
# 327881      STJ  SUP  GABINETE DO MINISTRO REYNALDO SOARES DA FONSECA  2024
# 396261      STJ  SUP                                     PRESIDÃNCIA  2024
# 250277      STJ  SUP         GABINETE DO MINISTRO JOEL ILAN PACIORNIK  2024
# 332492      STJ  SUP  GABINETE DO MINISTRO REYNALDO SOARES DA FONSECA  2024
#
#         Mes                   Processo  Codigo_da_Ultima_classe  \
# 449690    8  0014948-50.2024.3.00.0000                     1720
# 327881   11  0000071-06.2003.8.05.0091                    11881
# 396261   10  0337604-25.2024.3.00.0000                     1720
# 250277    3  0464241-55.2023.3.00.0000                     1720
# 332492    6  0124425-08.2024.3.00.0000                     1720
#
#              Nome_da_ultima_classe Codigos_assuntos Data_de_inicio  \
# 449690               HABEAS CORPUS           {3608}     2024-01-26
# 327881  AGRAVO EM RECURSO ESPECIAL           {3631}     2024-06-07
# 396261               HABEAS CORPUS          {10636}     2024-09-06
# 250277               HABEAS CORPUS      {3608,4355}     2023-12-26
# 332492               HABEAS CORPUS           {3608}     2024-04-12
#
#        Data_de_Referencia      Formato  Codigo_orgao   Status
# 449690         2024-08-27  EletrÃ´nico         87914  Baixado
# 327881         2024-11-29  EletrÃ´nico         76774  Baixado
# 396261         2024-10-04  EletrÃ´nico         76789  Baixado
# 250277         2024-03-12  EletrÃ´nico         76757  Baixado
# 332492         2024-06-10  EletrÃ´nico         76774  Baixado

# %% [markdown]
# **Normalização do nome das colunas**

# %%
dfs = [df_STJ1, df_STJ2, df_STJ3, df_STJ4, df_STJ5]
for i in range(len(dfs)):
    dfs[i].columns = dfs[i].columns.str.strip().str.lower()

df_STJ = pd.concat(dfs, ignore_index=True)
display(df_STJ.head(5))
# Out:
#   tribunal grau                             nome_orgao     ano   mes  \
# 0      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   5.0
# 1      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024.0  11.0
# 2      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   9.0
# 3      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0  11.0
# 4      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   1.0
#
#                     processo  codigo_da_ultima_classe  \
# 0  5009921-50.2020.4.03.6183                   1032.0
# 1  0414234-25.2024.3.00.0000                   1720.0
# 2        sigiloso(709521197)                  11881.0
# 3  0802709-59.2023.8.12.0001                  11881.0
# 4  5006641-38.2016.8.13.0480                  11881.0
#
#         nome_da_ultima_classe codigos_assuntos data_de_referencia  \
# 0            RECURSO ESPECIAL      {6176,6182}         2024-05-10
# 1               HABEAS CORPUS      {5566,3546}         2024-11-04
# 2  AGRAVO EM RECURSO ESPECIAL           {3465}         2024-09-17
# 3  AGRAVO EM RECURSO ESPECIAL           {9607}         2024-11-11
# 4  AGRAVO EM RECURSO ESPECIAL    {10504,10638}         2024-01-22
#
#        formato  codigo_orgao status data_de_inicio  \
# 0  EletrÃ´nico       12728.0   Novo            NaN
# 1  EletrÃ´nico       76776.0   Novo            NaN
# 2  EletrÃ´nico       12728.0   Novo            NaN
# 3  EletrÃ´nico       12728.0   Novo            NaN
# 4  EletrÃ´nico       12728.0   Novo            NaN
#
#   data_da_ultima_movimentacao  dias_de_antiguidade
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN

# %% [markdown]
# **Normalização da codigo_assuntos e seperação de código por linha sem {}**

# %%
if 'codigos_assuntos' in df_STJ.columns:
    df_STJ['codigos_assuntos'] = df_STJ['codigos_assuntos'].astype(str).str.replace(r"[{}]", "", regex=True).str.strip()

    df_STJ['codigos_assuntos'] = df_STJ['codigos_assuntos'].str.split(',')
    df_STJ = df_STJ.explode('codigos_assuntos')

    df_STJ['codigos_assuntos'] = pd.to_numeric(df_STJ['codigos_assuntos'], errors='coerce').astype('Int64')
else:
    print("Column 'codigos_assuntos' not found in DataFrame.")

display(df_STJ.head(5))
# Out:
#   tribunal grau                             nome_orgao     ano   mes  \
# 0      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   5.0
# 0      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   5.0
# 1      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024.0  11.0
# 1      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024.0  11.0
# 2      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   9.0
#
#                     processo  codigo_da_ultima_classe  \
# 0  5009921-50.2020.4.03.6183                   1032.0
# 0  5009921-50.2020.4.03.6183                   1032.0
# 1  0414234-25.2024.3.00.0000                   1720.0
# 1  0414234-25.2024.3.00.0000                   1720.0
# 2        sigiloso(709521197)                  11881.0
#
#         nome_da_ultima_classe  codigos_assuntos data_de_referencia  \
# 0            RECURSO ESPECIAL              6176         2024-05-10
# 0            RECURSO ESPECIAL              6182         2024-05-10
# 1               HABEAS CORPUS              5566         2024-11-04
# 1               HABEAS CORPUS              3546         2024-11-04
# 2  AGRAVO EM RECURSO ESPECIAL              3465         2024-09-17
#
#        formato  codigo_orgao status data_de_inicio  \
# 0  EletrÃ´nico       12728.0   Novo            NaN
# 0  EletrÃ´nico       12728.0   Novo            NaN
# 1  EletrÃ´nico       76776.0   Novo            NaN
# 1  EletrÃ´nico       76776.0   Novo            NaN
# 2  EletrÃ´nico       12728.0   Novo            NaN
#
#   data_da_ultima_movimentacao  dias_de_antiguidade
# 0                         NaN                  NaN
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN

# %% [markdown]
# **Arquivo de assustos e remoção das colunas desnecessárias**

# %%
df_assuntos = pd.read_csv("/content/assuntos.csv",  sep=';', on_bad_lines='skip')

display(df_assuntos.head(5))
# Out:
#   situacao        dat_alteracao  codigo  \
# 0        A  2020-11-23 17:54:47   14087
# 1        A  2020-11-23 17:55:16   14088
# 2        A  2023-03-31 13:54:33   14100
# 3        A  2023-03-31 13:51:20   14101
# 4        A  2023-03-31 13:43:28   14102
#
#                                            descricao  cod_pai cod_filhos  \
# 0                                  Natureza Jurídica  14083.0        NaN
# 1                            Honorários Advocatícios  14083.0        NaN
# 2  (Fato até 10/01/2023) Injúria Preconceituosa e...  12543.0        NaN
# 3  (Fato até 10/01/2023) Injúria Preconceituosa e...  12543.0        NaN
# 4  (Fato até 10/01/2023) Injúria Preconceituosa e...  12543.0        NaN
#
#   cod_filhos_ativos  nivel
# 0               NaN      4
# 1               NaN      4
# 2               NaN      5
# 3               NaN      5
# 4               NaN      5

# %%
df_assuntos =df_assuntos.drop(columns=['situacao', 'dat_alteracao', 'cod_pai',  'cod_filhos', 'cod_filhos_ativos', 'nivel'])

display(df_assuntos.head(5))
# Out:
#    codigo                                          descricao
# 0   14087                                  Natureza Jurídica
# 1   14088                            Honorários Advocatícios
# 2   14100  (Fato até 10/01/2023) Injúria Preconceituosa e...
# 3   14101  (Fato até 10/01/2023) Injúria Preconceituosa e...
# 4   14102  (Fato até 10/01/2023) Injúria Preconceituosa e...

# %% [markdown]
# **Relação entre codigos_assuntos e codigo e criação da coluna nome_assuntos**

# %%
df_STJ['codigos_assuntos'] = pd.to_numeric(df_STJ['codigos_assuntos'], errors='coerce').astype('Int64')

df_assuntos['codigo'] = pd.to_numeric(df_assuntos['codigo'], errors='coerce').astype('Int64')

df_resultado = df_STJ.merge(df_assuntos, left_on='codigos_assuntos', right_on='codigo', how='left')

df_resultado.head(5)
# Out:
#   tribunal grau                             nome_orgao     ano   mes  \
# 0      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   5.0
# 1      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   5.0
# 2      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024.0  11.0
# 3      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024.0  11.0
# 4      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024.0   9.0
#
#                     processo  codigo_da_ultima_classe  \
# 0  5009921-50.2020.4.03.6183                   1032.0
# 1  5009921-50.2020.4.03.6183                   1032.0
# 2  0414234-25.2024.3.00.0000                   1720.0
# 3  0414234-25.2024.3.00.0000                   1720.0
# 4        sigiloso(709521197)                  11881.0
#
#         nome_da_ultima_classe  codigos_assuntos data_de_referencia  \
# 0            RECURSO ESPECIAL              6176         2024-05-10
# 1            RECURSO ESPECIAL              6182         2024-05-10
# 2               HABEAS CORPUS              5566         2024-11-04
# 3               HABEAS CORPUS              3546         2024-11-04
# 4  AGRAVO EM RECURSO ESPECIAL              3465         2024-09-17
#
#        formato  codigo_orgao status data_de_inicio  \
# 0  EletrÃ´nico       12728.0   Novo            NaN
# 1  EletrÃ´nico       12728.0   Novo            NaN
# 2  EletrÃ´nico       76776.0   Novo            NaN
# 3  EletrÃ´nico       76776.0   Novo            NaN
# 4  EletrÃ´nico       12728.0   Novo            NaN
#
#   data_da_ultima_movimentacao  dias_de_antiguidade  codigo  \
# 0                         NaN                  NaN    6176
# 1                         NaN                  NaN    6182
# 2                         NaN                  NaN    5566
# 3                         NaN                  NaN    3546
# 4                         NaN                  NaN    3465
#
#                                            descricao
# 0                    Parcelas de benefício não pagas
# 1  Averbação/Cômputo/Conversão de tempo de serviç...
# 2                                     Roubo Majorado
# 3  Adulteração de Sinal Identificador de Veículo ...
# 4                                           Estupro

# %% [markdown]
# **Definição de ano e mes como inteiros e não float**

# %%
df_STJ = pd.concat([ df_resultado], ignore_index=True)

df_STJ['ano'] = df_STJ['ano'].astype(int)
df_STJ['mes'] = df_STJ['mes'].astype(int)
df_STJ['codigo_da_ultima_classe'] = df_STJ['codigo_da_ultima_classe'].astype(int)
df_STJ['codigo_orgao'] = df_STJ['codigo_orgao'].astype(int)

df_STJ.head(5)
# Out:
#   tribunal grau                             nome_orgao   ano  mes  \
# 0      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024    5
# 1      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024    5
# 2      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024   11
# 3      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024   11
# 4      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024    9
#
#                     processo  codigo_da_ultima_classe  \
# 0  5009921-50.2020.4.03.6183                     1032
# 1  5009921-50.2020.4.03.6183                     1032
# 2  0414234-25.2024.3.00.0000                     1720
# 3  0414234-25.2024.3.00.0000                     1720
# 4        sigiloso(709521197)                    11881
#
#         nome_da_ultima_classe  codigos_assuntos data_de_referencia  \
# 0            RECURSO ESPECIAL              6176         2024-05-10
# 1            RECURSO ESPECIAL              6182         2024-05-10
# 2               HABEAS CORPUS              5566         2024-11-04
# 3               HABEAS CORPUS              3546         2024-11-04
# 4  AGRAVO EM RECURSO ESPECIAL              3465         2024-09-17
#
#        formato  codigo_orgao status data_de_inicio  \
# 0  EletrÃ´nico         12728   Novo            NaN
# 1  EletrÃ´nico         12728   Novo            NaN
# 2  EletrÃ´nico         76776   Novo            NaN
# 3  EletrÃ´nico         76776   Novo            NaN
# 4  EletrÃ´nico         12728   Novo            NaN
#
#   data_da_ultima_movimentacao  dias_de_antiguidade  codigo  \
# 0                         NaN                  NaN    6176
# 1                         NaN                  NaN    6182
# 2                         NaN                  NaN    5566
# 3                         NaN                  NaN    3546
# 4                         NaN                  NaN    3465
#
#                                            descricao
# 0                    Parcelas de benefício não pagas
# 1  Averbação/Cômputo/Conversão de tempo de serviç...
# 2                                     Roubo Majorado
# 3  Adulteração de Sinal Identificador de Veículo ...
# 4                                           Estupro

# %%
df_STJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6682 entries, 0 to 6681
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   tribunal                     6682 non-null   object
#  1   grau                         6682 non-null   object
#  2   nome_orgao                   6682 non-null   object
#  3   ano                          6682 non-null   int64
#  4   mes                          6682 non-null   int64
#  5   processo                     6682 non-null   object
#  6   codigo_da_ultima_classe      6682 non-null   int64
#  7   nome_da_ultima_classe        6682 non-null   object
#  8   codigos_assuntos             6675 non-null   Int64
#  9   data_de_referencia           4252 non-null   object
#  10  formato                      6682 non-null   object
#  11  codigo_orgao                 6682 non-null   int64
#  12  status                       6682 non-null   object
#  13  data_de_inicio               3427 non-null   object
#  14  data_da_ultima_movimentacao  2430 non-null   object
#  15  dias_de_antiguidade          2430 non-null   float64
#  16  codigo                       6675 non-null   Int64
#  17  descricao                    6675 non-null   object
# dtypes: Int64(2), float64(1), int64(4), object(11)
# memory usage: 952.8+ KB

# %% [markdown]
# **Salvando arquivo**

# %%
df_STJ["nome_orgao"] = df_STJ["nome_orgao"].replace("JUSTIAA", "JUSTIÇA", regex=True)

display(df_STJ.head(5))
# Out:
#   tribunal grau                             nome_orgao   ano  mes  \
# 0      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024    5
# 1      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024    5
# 2      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024   11
# 3      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024   11
# 4      STJ  SUP          SUPERIOR TRIBUNAL DE JUSTIÃA  2024    9
#
#                     processo  codigo_da_ultima_classe  \
# 0  5009921-50.2020.4.03.6183                     1032
# 1  5009921-50.2020.4.03.6183                     1032
# 2  0414234-25.2024.3.00.0000                     1720
# 3  0414234-25.2024.3.00.0000                     1720
# 4        sigiloso(709521197)                    11881
#
#         nome_da_ultima_classe  codigos_assuntos data_de_referencia  \
# 0            RECURSO ESPECIAL              6176         2024-05-10
# 1            RECURSO ESPECIAL              6182         2024-05-10
# 2               HABEAS CORPUS              5566         2024-11-04
# 3               HABEAS CORPUS              3546         2024-11-04
# 4  AGRAVO EM RECURSO ESPECIAL              3465         2024-09-17
#
#        formato  codigo_orgao status data_de_inicio  \
# 0  EletrÃ´nico         12728   Novo            NaN
# 1  EletrÃ´nico         12728   Novo            NaN
# 2  EletrÃ´nico         76776   Novo            NaN
# 3  EletrÃ´nico         76776   Novo            NaN
# 4  EletrÃ´nico         12728   Novo            NaN
#
#   data_da_ultima_movimentacao  dias_de_antiguidade  codigo  \
# 0                         NaN                  NaN    6176
# 1                         NaN                  NaN    6182
# 2                         NaN                  NaN    5566
# 3                         NaN                  NaN    3546
# 4                         NaN                  NaN    3465
#
#                                            descricao
# 0                    Parcelas de benefício não pagas
# 1  Averbação/Cômputo/Conversão de tempo de serviç...
# 2                                     Roubo Majorado
# 3  Adulteração de Sinal Identificador de Veículo ...
# 4                                           Estupro

# %%
import unicodedata

# Função para remover acentos e corrigir caracteres
def normalizar_texto(texto):
    if isinstance(texto, str):
        texto = unicodedata.normalize('NFKD', texto).encode('ascii', 'ignore').decode('utf-8')  # Remove acentos
        texto = texto.replace("", "ç").replace("", "ç")
    return texto

# Aplicar a função de normalização a todas as colunas do tipo string
df_STJ = df_STJ.applymap(normalizar_texto)

# Exibir DataFrame corrigido
display(df_STJ.head(5))
# Out:
# <ipython-input-72-bcce0a718201>:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_STJ = df_STJ.applymap(normalizar_texto)
#   tribunal grau                             nome_orgao   ano  mes  \
# 0      STJ  SUP           SUPERIOR TRIBUNAL DE JUSTIAA  2024    5
# 1      STJ  SUP           SUPERIOR TRIBUNAL DE JUSTIAA  2024    5
# 2      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024   11
# 3      STJ  SUP  GABINETE DO MINISTRO ROGERIO SCHIETTI  2024   11
# 4      STJ  SUP           SUPERIOR TRIBUNAL DE JUSTIAA  2024    9
#
#                     processo  codigo_da_ultima_classe  \
# 0  5009921-50.2020.4.03.6183                     1032
# 1  5009921-50.2020.4.03.6183                     1032
# 2  0414234-25.2024.3.00.0000                     1720
# 3  0414234-25.2024.3.00.0000                     1720
# 4        sigiloso(709521197)                    11881
#
#         nome_da_ultima_classe  codigos_assuntos data_de_referencia  \
# 0            RECURSO ESPECIAL            6176.0         2024-05-10
# 1            RECURSO ESPECIAL            6182.0         2024-05-10
# 2               HABEAS CORPUS            5566.0         2024-11-04
# 3               HABEAS CORPUS            3546.0         2024-11-04
# 4  AGRAVO EM RECURSO ESPECIAL            3465.0         2024-09-17
#
#        formato  codigo_orgao status data_de_inicio  \
# 0  EletrA nico         12728   Novo            NaN
# 1  EletrA nico         12728   Novo            NaN
# 2  EletrA nico         76776   Novo            NaN
# 3  EletrA nico         76776   Novo            NaN
# 4  EletrA nico         12728   Novo            NaN
#
#   data_da_ultima_movimentacao  dias_de_antiguidade  codigo  \
# 0                         NaN                  NaN  6176.0
# 1                         NaN                  NaN  6182.0
# 2                         NaN                  NaN  5566.0
# 3                         NaN                  NaN  3546.0
# 4                         NaN                  NaN  3465.0
#
#                                            descricao
# 0                    Parcelas de beneficio nao pagas
# 1  Averbacao/Computo/Conversao de tempo de servic...
# 2                                     Roubo Majorado
# 3  Adulteracao de Sinal Identificador de Veiculo ...
# 4                                           Estupro

# %%
df_STJ.to_csv('STJ.csv', index=False)
df_STJ.to_excel('STJ.xlsx', index=False)

# %% [markdown]
# #**STM**

# %% [markdown]
# **Seleção de Dados**

# %%
STM_cn = '/content/STM_CN.csv'
STM_cpl = '/content/STM_CPL.csv'
STM_cpl15 = '/content/STM_CPL_15anos.csv'
STM_julg = '/content/STM_Sent.csv'
STM_baix = '/content/STM_TBaix.csv'


STM_cn = pd.read_csv(STM_cn, encoding='latin-1', sep=';', on_bad_lines='skip')
STM_cpl = pd.read_csv(STM_cpl, encoding='latin-1', sep=';', on_bad_lines='skip')
STM_cpl15 = pd.read_csv(STM_cpl15, encoding='latin-1', sep=';', on_bad_lines='skip')
STM_julg = pd.read_csv(STM_julg, encoding='latin-1', sep=';', on_bad_lines='skip')
STM_baix = pd.read_csv(STM_baix, encoding='latin-1', sep=';', on_bad_lines='skip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-76-478baa91437d> in <cell line: 0>()
#       6
#       7
# ----> 8 STM_cn = pd.read_csv(STM_cn, encoding='latin-1', sep=';', on_bad_lines='skip')
#       9 STM_cpl = pd.read_csv(STM_cpl, encoding='latin-1', sep=';', on_bad_lines='skip')
#      10 STM_cpl15 = pd.read_csv(STM_cpl15, encoding='latin-1', sep=';', on_bad_lines='skip')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/STM_CN.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
STM_cn = STM_cn.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Codigos_classes', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM1 = STM_cn.copy()
df_STM1['Status'] = 'Novo'

df_STM1.head(5)

# %%
STM_cpl = STM_cpl.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Codigos_classes', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM2 = STM_cpl.copy()
df_STM2['Status'] = 'Pendente'

df_STM2.head(5)

# %%
STM_cpl15 = STM_cpl15.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Codigos_classes', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM3 = STM_cpl15.copy()
df_STM3['Status'] = 'Pendente +15'

df_STM3.head(5)

# %%
STM_julg =STM_julg.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Codigos_classes', 'Data_da_decisao:_Situacao:_Movimento', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM4 = STM_julg.copy()
df_STM4['Status'] = 'Julgado'

df_STM4.head(5)

# %%
STM_baix =STM_baix.drop(columns=['UF', 'Recurso_Originario', 'Municipio', 'Recurso', 'Procedimento', 'Codigos_Classes', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM5 = STM_baix.copy()
df_STM5['Status'] = 'Baixado'

df_STM5.head(5)

# %% [markdown]
# **Normalização do nome das colunas**

# %%
dfs = [df_STM1, df_STM2, df_STM3, df_STM4, df_STM5]
for i in range(len(dfs)):
    dfs[i].columns = dfs[i].columns.str.strip().str.lower()

df_STM = pd.concat(dfs, ignore_index=True)
display(df_STM.head(5))

# %% [markdown]
# **Normalização da codigo_assuntos e seperação de código por linha sem {}**

# %%
if 'codigos_assuntos' in df_STM.columns:
    df_STM['codigos_assuntos'] = df_STM['codigos_assuntos'].astype(str).str.replace(r"[{}]", "", regex=True).str.strip()

    df_STM['codigos_assuntos'] = df_STM['codigos_assuntos'].str.split(',')
    df_STM = df_STM.explode('codigos_assuntos')

    df_STM['codigos_assuntos'] = pd.to_numeric(df_STM['codigos_assuntos'], errors='coerce')#.astype('Int64')
else:
    print("Column 'codigos_assuntos' not found in DataFrame.")

display(df_STM.head(5))

# %% [markdown]
# **Arquivo de assuntos e remoção das colunas desnecessárias**

# %%
df_assuntos = pd.read_csv("/content/assuntos.csv",  sep=';', on_bad_lines='skip')

display(df_assuntos.head(5))

# %%
df_assuntos =df_assuntos.drop(columns=['situacao', 'dat_alteracao', 'cod_pai',  'cod_filhos', 'cod_filhos_ativos', 'nivel'])

display(df_assuntos.head(5))

# %% [markdown]
# **Relação entre codigos_assuntos e codigo e criação da coluna nome assuntos**

# %%
df_STM['codigos_assuntos'] = pd.to_numeric(df_STM['codigos_assuntos'], errors='coerce').astype('Int64')

df_assuntos['codigo'] = pd.to_numeric(df_assuntos['codigo'], errors='coerce').astype('Int64')

df_resultado = df_STM.merge(df_assuntos, left_on='codigos_assuntos', right_on='codigo', how='left')

df_resultado.head(5)

# %% [markdown]
# **Definição de ano e mes como inteiros e não float**

# %%
df_STM = pd.concat([ df_resultado], ignore_index=True)

df_STM['ano'] = df_STM['ano'].astype(int)
df_STM['mes'] = df_STM['mes'].astype(int)

df_STM.head(5)

# %% [markdown]
# **Salvando arquivo**

# %%
df_STM.to_csv('STMcsv', index=False)
df_STM.to_excel('STM.xlsx', index=False)

# %% [markdown]
# #**TSE**

# %% [markdown]
# **Seleção de Dados**

# %%
TSE_cn = '/content/TSE_CN.csv'
TSE_cpl = '/content/TSE_CPL.csv'
TSE_cpl15 = '/content/TSE_CPL_15anos.csv'
TSE_julg = '/content/TSE_Sent.csv'
TSE_baix = '/content/TSE_TBaix.csv'


TSE_cn = pd.read_csv(TSE_cn, encoding='latin-1', sep=';', on_bad_lines='skip')
TSE_cpl = pd.read_csv(TSE_cpl, encoding='latin-1', sep=';', on_bad_lines='skip')
TSE_cpl15 = pd.read_csv(TSE_cpl15, encoding='latin-1', sep=';', on_bad_lines='skip')
TSE_julg = pd.read_csv(TSE_julg, encoding='latin-1', sep=';', on_bad_lines='skip')
TSE_baix = pd.read_csv(TSE_baix, encoding='latin-1', sep=';', on_bad_lines='skip')

# %%
TSE_cn = TSE_cn.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Codigos_classes', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TSE_cn = TSE_cn.dropna()

df_TSE1 = TSE_cn.sample(n=1000, random_state=42).copy()
df_TSE1['Status'] = 'Novo'

df_TSE1.head(5)

# %%
TSE_cpl = TSE_cpl.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Codigos_classes', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TSE_cpl = TSE_cpl.dropna()

df_TSE2 = TSE_cpl.sample(n=1000, random_state=42).copy()
df_TSE2['Status'] = 'Pendente'

df_TSE2.head(5)

# %%
TSE_cpl15 = TSE_cpl15.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Codigos_classes',  'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_TSE3 = TSE_cpl15.copy()
df_TSE3['Status'] = 'Pendente +15'

df_TSE3.head(5)

# %%
TSE_julg = TSE_julg.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Codigos_classes', 'Data_da_decisao:_Situacao:_Movimento', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TSE_julg = TSE_julg.dropna()

df_TSE4 = TSE_julg.sample(n=1000, random_state=42).copy()
df_TSE4['Status'] = 'Julgados'

df_TSE4.head(5)

# %%
TSE_baix = TSE_baix.drop(columns=['UF', 'Recurso_Originario', 'Municipio', 'Recurso', 'Procedimento', 'Codigos_Classes', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TSE_baix = TSE_baix.dropna()

df_TSE5 = TSE_baix.sample(n=600, random_state=42).copy()
df_TSE5['Status'] = 'Baixado'

df_TSE5.head(5)

# %% [markdown]
# **Normalização do nome das colunas**

# %%
dfs = [df_TSE1, df_TSE2, df_TSE3, df_TSE4, df_TSE5]
for i in range(len(dfs)):
    dfs[i].columns = dfs[i].columns.str.strip().str.lower()

df_TSE = pd.concat(dfs, ignore_index=True)
display(df_TSE.head(5))

# %% [markdown]
# **Normalização da codigo_assuntos e seperação de código por linha sem {}**

# %%
if 'codigos_assuntos' in df_TSE.columns:
    df_TSE['codigos_assuntos'] = df_TSE['codigos_assuntos'].astype(str).str.replace(r"[{}]", "", regex=True).str.strip()

    df_TSE['codigos_assuntos'] = df_TSE['codigos_assuntos'].str.split(',')
    df_TSE = df_TSE.explode('codigos_assuntos')

    df_TSE['codigos_assuntos'] = pd.to_numeric(df_TSE['codigos_assuntos'], errors='coerce')#.astype('Int64')
else:
    print("Column 'codigos_assuntos' not found in DataFrame.")

display(df_TSE.head(5))

# %% [markdown]
# **Arquivo de assuntos e remoção das colunas desnecessárias**

# %%
df_assuntos = pd.read_csv("/content/assuntos.csv",  sep=';', on_bad_lines='skip')

display(df_assuntos.head(5))

# %%
df_assuntos =df_assuntos.drop(columns=['situacao', 'dat_alteracao', 'cod_pai',  'cod_filhos', 'cod_filhos_ativos', 'nivel'])

display(df_assuntos.head(5))

# %% [markdown]
# **Relação entre codigos_assuntos e codigo e criação da coluna nome assuntos**

# %%
df_TSE['codigos_assuntos'] = pd.to_numeric(df_TSE['codigos_assuntos'], errors='coerce').astype('Int64')

df_assuntos['codigo'] = pd.to_numeric(df_assuntos['codigo'], errors='coerce').astype('Int64')

df_resultado = df_TSE.merge(df_assuntos, left_on='codigos_assuntos', right_on='codigo', how='left')

df_resultado.head(5)

# %% [markdown]
# Definição de ano e mes como inteiros e não float
# **negrito**

# %%
df_TSE = pd.concat([ df_resultado], ignore_index=True)

df_TSE['ano'] = df_TSE['ano'].astype(int)
df_TSE['mes'] = df_TSE['mes'].astype(int)

df_TSE.head(5)

# %% [markdown]
# **Salvando arquivo**

# %%
df_TSE.to_csv('TSE.csv', index=False)
df_TSE.to_excel('TSE.xlsx', index=False)

# %% [markdown]
# #**TST**

# %% [markdown]
# **Seleção de Dados**

# %%
TST_cn = '/content/TST_CN.csv'
TST_cpl = '/content/TST_CPL.csv'
TST_cpl15 = '/content/TST_CPL_15anos.csv'
TST_julg = '/content/TST_Sent.csv'
TST_baix = '/content/TST_TBaix.csv'


TST_cn = pd.read_csv(TST_cn, encoding='latin-1', sep=';', on_bad_lines='skip')
TST_cpl = pd.read_csv(TST_cpl, encoding='latin-1', sep=';', on_bad_lines='skip')
TST_cpl15 = pd.read_csv(TST_cpl15, encoding='latin-1', sep=';', on_bad_lines='skip')
TST_julg = pd.read_csv(TST_julg, encoding='latin-1', sep=';', on_bad_lines='skip')
TST_baix = pd.read_csv(TST_baix, encoding='latin-1', sep=';', on_bad_lines='skip')

# %%
TST_cn = TST_cn.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Codigos_classes', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TST_cn = TST_cn.dropna()

df_TST1 = TST_cn.sample(n=1000, random_state=42).copy()
df_TST1['Status'] = 'Novo'

df_TST1.head(5)

# %%
TST_cpl = TST_cpl.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Codigos_classes', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TST_cpl = TST_cpl.dropna()

df_TST2 = TST_cpl.sample(n=1000, random_state=42).copy()
df_TST2['Status'] = 'Pendente'

df_TST2.head(5)

# %%
TST_cpl15 = TST_cpl15.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Codigos_classes', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_TST3 = TST_cpl15.copy()
df_TST3['Status'] = 'Pendente +15'

df_TST3.head(5)

# %%
TST_julg = TST_julg.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Codigos_classes', 'Data_da_decisao:_Situacao:_Movimento', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])
TST_julg = TST_julg.dropna()

df_TST4 = TST_julg.sample(n=1000, random_state=42).copy()
df_TST4['Status'] = 'Julgado'

df_TST4.head(5)

# %%
TST_baix = TST_baix.drop(columns=['UF', 'Recurso_Originario', 'Municipio', 'Recurso', 'Procedimento', 'Codigos_Classes', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TST_baix = TST_baix.dropna()

df_TST5 = TST_baix.sample(n=600, random_state=42).copy()
df_TST5['Status'] = 'Baixado'

df_TST5.head(5)

# %% [markdown]
# **Normalização do nome das colunas**

# %%
dfs = [df_TST1, df_TST2, df_TST3, df_TST4, df_TST5]
for i in range(len(dfs)):
    dfs[i].columns = dfs[i].columns.str.strip().str.lower()

df_TST = pd.concat(dfs, ignore_index=True)
display(df_TST.head(5))

# %% [markdown]
# **Normalização da codigo_assuntos e seperação de código por linha sem {}**

# %%
if 'codigos_assuntos' in df_TST.columns:
    df_TST['codigos_assuntos'] = df_TST['codigos_assuntos'].astype(str).str.replace(r"[{}]", "", regex=True).str.strip()

    df_TST['codigos_assuntos'] = df_TST['codigos_assuntos'].str.split(',')
    df_TST = df_TST.explode('codigos_assuntos')

    df_TST['codigos_assuntos'] = pd.to_numeric(df_TST['codigos_assuntos'], errors='coerce')#.astype('Int64')
else:
    print("Column 'codigos_assuntos' not found in DataFrame.")

display(df_TST.head(5))

# %% [markdown]
# **Arquivo de assuntos e remoção das colunas desnecessárias**

# %%
df_assuntos = pd.read_csv("/content/assuntos.csv",  sep=';', on_bad_lines='skip')

display(df_assuntos.head(5))

# %%
df_assuntos =df_assuntos.drop(columns=['situacao', 'dat_alteracao', 'cod_pai',  'cod_filhos', 'cod_filhos_ativos', 'nivel'])

display(df_assuntos.head(5))

# %% [markdown]
# **Relação entre codigos_assuntos e codigo e criação da coluna nome assuntos**

# %%
df_TST['codigos_assuntos'] = pd.to_numeric(df_TST['codigos_assuntos'], errors='coerce').astype('Int64')

df_assuntos['codigo'] = pd.to_numeric(df_assuntos['codigo'], errors='coerce').astype('Int64')

df_resultado = df_TST.merge(df_assuntos, left_on='codigos_assuntos', right_on='codigo', how='left')

df_resultado.head(5)

# %% [markdown]
# **Definição de ano e mes como inteiros e não float**

# %%
df_TST = pd.concat([ df_resultado], ignore_index=True)

df_TST['ano'] = df_TST['ano'].astype(int)
df_TST['mes'] = df_TST['mes'].astype(int)

df_TST.head(5)

# %% [markdown]
# **Salvando arquivo**

# %%
df_TST.to_csv('TST.csv', index=False)
df_TST.to_excel('TST.xlsx', index=False)
