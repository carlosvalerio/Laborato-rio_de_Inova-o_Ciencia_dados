# %% [markdown]
# #**DATASETS**

# %% [markdown]
# Link para download dos arquivos ('https://drive.google.com/drive/folders/14TcAxrrtD0WOuG-pAkCVeE-17aouxiB6?usp=sharing)

# %% [markdown]
# **Importação das bibliotecas**

# %%
import pandas as pd

# %% [markdown]
# #**STJ**

# %% [markdown]
# **Seleção de Dados**

# %%
STJ_cn = '/content/STJ_CN.csv'
STJ_cpl = '/content/STJ_CPL.csv'
STJ_cpl15 = '/content/STJ_CPL_15anos.csv'
STJ_julg = '/content/STJ_Sent.csv'
STJ_baix = '/content/STJ_TBaix.csv'


STJ_cn = pd.read_csv(STJ_cn, encoding='latin-1', sep=';', on_bad_lines='skip')
STJ_cpl = pd.read_csv(STJ_cpl, encoding='latin-1', sep=';', on_bad_lines='skip')
STJ_cpl15 = pd.read_csv(STJ_cpl15, encoding='latin-1', sep=';', on_bad_lines='skip')
STJ_julg = pd.read_csv(STJ_julg, encoding='latin-1', sep=';', on_bad_lines='skip')
STJ_baix = pd.read_csv(STJ_baix, encoding='latin-1', sep=';', on_bad_lines='skip')

# %%
STJ_cn = STJ_cn.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

STJ_cn = STJ_cn.dropna()

df_STJ1 = STJ_cn.sample(n=1000, random_state=42).copy()
df_STJ1['Status'] = 'Novo'

df_STJ1.head(5)
# Out:
#        Tribunal Grau                     Nome_Orgao   Ano  Mes  \
# 9377        STJ  SUP  SUPERIOR TRIBUNAL DE JUSTIÃA  2024    1
# 211048      STJ  SUP  SUPERIOR TRIBUNAL DE JUSTIÃA  2025    1
# 36525       STJ  SUP  SUPERIOR TRIBUNAL DE JUSTIÃA  2024    8
# 456302      STJ  SUP                   PRESIDÃNCIA  2024   12
# 166828      STJ  SUP  SUPERIOR TRIBUNAL DE JUSTIÃA  2024    8
#
#                          Processo  Codigo_da_Ultima_classe  \
# 9377    0093715-28.2022.8.19.0000                    11881
# 211048  1032460-20.2022.8.26.0562                    11881
# 36525   0112785-32.2014.8.09.0051                    11881
# 456302  0470194-63.2024.3.00.0000                     1720
# 166828  0808892-65.2023.8.15.0000                    11881
#
#              Nome_da_Ultima_classe Codigos_classes  \
# 9377    AGRAVO EM RECURSO ESPECIAL         {11881}
# 211048  AGRAVO EM RECURSO ESPECIAL         {11881}
# 36525   AGRAVO EM RECURSO ESPECIAL         {11881}
# 456302               HABEAS CORPUS          {1720}
# 166828  AGRAVO EM RECURSO ESPECIAL         {11881}
#
#                    Codigos_assuntos Data_de_Referencia      Formato  \
# 9377    {9587,7779,9596,7780,11860}         2024-01-30  EletrÃ´nico
# 211048                      {10240}         2025-01-29  EletrÃ´nico
# 36525                        {4951}         2024-08-08  EletrÃ´nico
# 456302                       {3372}         2024-12-10  EletrÃ´nico
# 166828                {10458,10939}         2024-08-19  EletrÃ´nico
#
#         Codigo_Orgao Status
# 9377           12728   Novo
# 211048         12728   Novo
# 36525          12728   Novo
# 456302         76789   Novo
# 166828         12728   Novo

# %%
STJ_cpl = STJ_cpl.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

STJ_cpl = STJ_cpl.dropna()

df_STJ2 = STJ_cpl.sample(n=1000, random_state=42).copy()
df_STJ2['Status'] = 'Pendente'

df_STJ2.head(5)
# Out:
#        Tribunal Grau                                         Nome_Orgao   Ano  \
# 330944      STJ  SUP                      SUPERIOR TRIBUNAL DE JUSTIÃA  2025
# 88932       STJ  SUP     GABINETE DO MINISTRO ANTONIO SALDANHA PALHEIRO  2025
# 6080        STJ  SUP               GABINETE DO MINISTRO AFRÃNIO VILELA  2025
# 115445      STJ  SUP  GABINETE DA MINISTRA MARIA THEREZA DE ASSIS MOURA  2025
# 85516       STJ  SUP  GABINETE DO DESEMBARGADOR CONVOCADO OTÃ?VIO DE...  2025
#
#         Mes                   Processo  Codigo_da_Ultima_classe  \
# 330944    1  1007608-19.2018.8.11.0002                    11881
# 88932     1  0014618-60.2018.8.16.0013                    11881
# 6080      1  0009486-44.2017.8.07.0001                     1032
# 115445    1  0012176-73.2010.4.03.6100                    11881
# 85516     1  1522952-45.2020.8.26.0050                    11881
#
#              Nome_da_Ultima_classe Codigos_classes  \
# 330944  AGRAVO EM RECURSO ESPECIAL         {11881}
# 88932   AGRAVO EM RECURSO ESPECIAL         {11881}
# 6080              RECURSO ESPECIAL          {1032}
# 115445  AGRAVO EM RECURSO ESPECIAL         {11881}
# 85516   AGRAVO EM RECURSO ESPECIAL         {11881}
#
#                        Codigos_assuntos Data_de_inicio  \
# 330944               {10433,10439,9047}     2024-12-19
# 88932                       {3417,3431}     2023-11-24
# 6080                            {10375}     2018-11-29
# 115445  {6064,5994,5987,6060,6068,6062}     2024-03-08
# 85516                            {3608}     2023-11-08
#
#        Data_da_ultima_movimentacao  Dias_de_antiguidade      Formato  \
# 330944                  2025-01-28                  7.0  EletrÃ´nico
# 88932                   2025-01-31                434.0  EletrÃ´nico
# 6080                    2025-02-03               2254.0  EletrÃ´nico
# 115445                  2024-08-26                319.0  EletrÃ´nico
# 85516                   2024-11-25                450.0  EletrÃ´nico
#
#         Codigo_Orgao    Status
# 330944         12728  Pendente
# 88932          76748  Pendente
# 6080           87913  Pendente
# 115445         76764  Pendente
# 85516          88421  Pendente

# %%
STJ_cpl15 = STJ_cpl15.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STJ3 = STJ_cpl15.copy()
df_STJ3['Status'] = 'Pendente +15'

df_STJ3.head(5)
# Out:
#   Tribunal Grau                                       Nome_Orgao   Ano  Mes  \
# 0      STJ  SUP  GABINETE DO MINISTRO ANTÃNIO DE PÃ?DUA RIBEIRO  2025    1
# 1      STJ  SUP             GABINETE DO MINISTRO HÃLIO MOSIMANN  2025    1
# 2      STJ  SUP                   PRESIDENTE DA PRIMEIRA SEÃÃO  2025    1
# 3      STJ  SUP                   PRESIDENTE DA PRIMEIRA SEÃÃO  2025    1
# 4      STJ  SUP                    SUPERIOR TRIBUNAL DE JUSTIÃA  2025    1
#
#                     Processo  Codigo_da_Ultima_classe  Nome_da_Ultima_classe  \
# 0  0011625-92.1991.3.00.0000                     1029  MANDADO DE SEGURANÃA
# 1  0000003-79.1992.3.00.0000                     1029  MANDADO DE SEGURANÃA
# 2  0014173-22.1993.3.00.0000                     1029  MANDADO DE SEGURANÃA
# 3  0022333-02.1994.3.00.0000                     1029  MANDADO DE SEGURANÃA
# 4  0024524-20.1994.3.00.0000                     1029  MANDADO DE SEGURANÃA
#
#   Codigos_classes Codigos_assuntos Data_de_inicio Data_da_ultima_movimentacao  \
# 0          {1029}           {9997}     1991-06-26                  2020-09-09
# 1          {1029}          {10097}     1992-01-02                  2022-11-29
# 2          {1029}          {10098}     2011-08-10                  2024-09-10
# 3          {1029}          {10098}     2011-08-10                  2024-09-20
# 4          {1029}          {10098}     2017-11-21                  2025-01-14
#
#    Dias_de_antiguidade      Formato  Codigo_Orgao        Status
# 0                12273  EletrÃ´nico         82881  Pendente +15
# 1                12083  EletrÃ´nico         82844  Pendente +15
# 2                11567  EletrÃ´nico         76780  Pendente +15
# 3                11179  EletrÃ´nico         76780  Pendente +15
# 4                11158  EletrÃ´nico         12728  Pendente +15

# %%
STJ_julg = STJ_julg.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Data_da_decisao:_Situacao:_Movimento', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

STJ_julg = STJ_julg.dropna()

df_STJ4 = STJ_julg.sample(n=1000, random_state=42).copy()
df_STJ4['Status'] = 'Julgado'

df_STJ4.head(5)
# Out:
#        Tribunal Grau                                         Nome_Orgao   Ano  \
# 309895      STJ  SUP       GABINETE DO MINISTRO MARCO AURÃLIO BELLIZZE  2024
# 72377       STJ  SUP                                       PRESIDÃNCIA  2024
# 654310      STJ  SUP  GABINETE DO DESEMBARGADOR CONVOCADO OTÃ?VIO DE...  2024
# 35442       STJ  SUP                                       PRESIDÃNCIA  2024
# 252130      STJ  SUP               GABINETE DO MINISTRO GURGEL DE FARIA  2024
#
#         Mes                   Processo Codigos_classes  \
# 309895    5  5546091-27.2020.8.09.0083         {11881}
# 72377     3  5001833-16.2015.4.04.7009         {11881}
# 654310   12  0434614-06.2023.3.00.0000          {1720}
# 35442     7  8003396-97.2022.8.05.0150         {11881}
# 252130    3  5027690-12.2021.4.02.5101     {1137,1032}
#
#         Codigo_da_Ultima_classe       Nome_da_Ultima_classe Codigos_assuntos  \
# 309895                    11881  AGRAVO EM RECURSO ESPECIAL           {4703}
# 72377                     11881  AGRAVO EM RECURSO ESPECIAL      {4839,4847}
# 654310                     1720               HABEAS CORPUS           {3608}
# 35442                     11881  AGRAVO EM RECURSO ESPECIAL           {5566}
# 252130                     1032            RECURSO ESPECIAL     {8928,10399}
#
#        Data_de_Referencia      Formato  Codigo_Orgao   Status
# 309895         2024-05-20  EletrÃ´nico         76761  Julgado
# 72377          2024-03-04  EletrÃ´nico         76789  Julgado
# 654310         2024-12-10  EletrÃ´nico         88421  Julgado
# 35442          2024-07-22  EletrÃ´nico         76789  Julgado
# 252130         2024-03-22  EletrÃ´nico         76753  Julgado

# %%
STJ_baix =STJ_baix.drop(columns=['UF', 'Recurso_Originario', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

STJ_baix = STJ_baix.dropna()

df_STJ5 = STJ_baix.sample(n=600, random_state=42).copy()
df_STJ5['Status'] = 'Baixado'

df_STJ5.head(5)
# Out:
#        Tribunal Grau                                       Nome_orgao   Ano  \
# 449690      STJ  SUP            GABINETE DA MINISTRA DANIELA TEIXEIRA  2024
# 327881      STJ  SUP  GABINETE DO MINISTRO REYNALDO SOARES DA FONSECA  2024
# 396261      STJ  SUP                                     PRESIDÃNCIA  2024
# 250277      STJ  SUP         GABINETE DO MINISTRO JOEL ILAN PACIORNIK  2024
# 332492      STJ  SUP  GABINETE DO MINISTRO REYNALDO SOARES DA FONSECA  2024
#
#         Mes                   Processo  Codigo_da_Ultima_classe  \
# 449690    8  0014948-50.2024.3.00.0000                     1720
# 327881   11  0000071-06.2003.8.05.0091                    11881
# 396261   10  0337604-25.2024.3.00.0000                     1720
# 250277    3  0464241-55.2023.3.00.0000                     1720
# 332492    6  0124425-08.2024.3.00.0000                     1720
#
#              Nome_da_ultima_classe Codigos_Classes Codigos_assuntos  \
# 449690               HABEAS CORPUS          {1720}           {3608}
# 327881  AGRAVO EM RECURSO ESPECIAL         {11881}           {3631}
# 396261               HABEAS CORPUS          {1720}          {10636}
# 250277               HABEAS CORPUS          {1720}      {3608,4355}
# 332492               HABEAS CORPUS          {1720}           {3608}
#
#        Data_de_inicio Data_de_Referencia      Formato  Codigo_orgao   Status
# 449690     2024-01-26         2024-08-27  EletrÃ´nico         87914  Baixado
# 327881     2024-06-07         2024-11-29  EletrÃ´nico         76774  Baixado
# 396261     2024-09-06         2024-10-04  EletrÃ´nico         76789  Baixado
# 250277     2023-12-26         2024-03-12  EletrÃ´nico         76757  Baixado
# 332492     2024-04-12         2024-06-10  EletrÃ´nico         76774  Baixado

# %%
df_STJ = pd.concat([df_STJ1, df_STJ2, df_STJ3, df_STJ4,]) #df_STJ5])
display(df_STJ.head(5))
# Out:
#        Tribunal Grau                     Nome_Orgao   Ano  Mes  \
# 9377        STJ  SUP  SUPERIOR TRIBUNAL DE JUSTIÃA  2024    1
# 211048      STJ  SUP  SUPERIOR TRIBUNAL DE JUSTIÃA  2025    1
# 36525       STJ  SUP  SUPERIOR TRIBUNAL DE JUSTIÃA  2024    8
# 456302      STJ  SUP                   PRESIDÃNCIA  2024   12
# 166828      STJ  SUP  SUPERIOR TRIBUNAL DE JUSTIÃA  2024    8
#
#                          Processo  Codigo_da_Ultima_classe  \
# 9377    0093715-28.2022.8.19.0000                    11881
# 211048  1032460-20.2022.8.26.0562                    11881
# 36525   0112785-32.2014.8.09.0051                    11881
# 456302  0470194-63.2024.3.00.0000                     1720
# 166828  0808892-65.2023.8.15.0000                    11881
#
#              Nome_da_Ultima_classe Codigos_classes  \
# 9377    AGRAVO EM RECURSO ESPECIAL         {11881}
# 211048  AGRAVO EM RECURSO ESPECIAL         {11881}
# 36525   AGRAVO EM RECURSO ESPECIAL         {11881}
# 456302               HABEAS CORPUS          {1720}
# 166828  AGRAVO EM RECURSO ESPECIAL         {11881}
#
#                    Codigos_assuntos Data_de_Referencia      Formato  \
# 9377    {9587,7779,9596,7780,11860}         2024-01-30  EletrÃ´nico
# 211048                      {10240}         2025-01-29  EletrÃ´nico
# 36525                        {4951}         2024-08-08  EletrÃ´nico
# 456302                       {3372}         2024-12-10  EletrÃ´nico
# 166828                {10458,10939}         2024-08-19  EletrÃ´nico
#
#         Codigo_Orgao Status Data_de_inicio Data_da_ultima_movimentacao  \
# 9377           12728   Novo            NaN                         NaN
# 211048         12728   Novo            NaN                         NaN
# 36525          12728   Novo            NaN                         NaN
# 456302         76789   Novo            NaN                         NaN
# 166828         12728   Novo            NaN                         NaN
#
#         Dias_de_antiguidade
# 9377                    NaN
# 211048                  NaN
# 36525                   NaN
# 456302                  NaN
# 166828                  NaN

# %%
df_STJ = pd.concat([df_STJ1, df_STJ2, df_STJ3, df_STJ4], ignore_index=True)

df_STJ['Ano'] = df_STJ['Ano'].astype(int)
df_STJ['Mes'] = df_STJ['Mes'].astype(int)

display(df_STJ)

df_STJ.to_csv('STJ.csv', index=False)
df_STJ.to_excel('STJ.xlsx', index=False)
# Out:
#      Tribunal Grau                                         Nome_Orgao   Ano  \
# 0         STJ  SUP                      SUPERIOR TRIBUNAL DE JUSTIÃA  2024
# 1         STJ  SUP                      SUPERIOR TRIBUNAL DE JUSTIÃA  2025
# 2         STJ  SUP                      SUPERIOR TRIBUNAL DE JUSTIÃA  2024
# 3         STJ  SUP                                       PRESIDÃNCIA  2024
# 4         STJ  SUP                      SUPERIOR TRIBUNAL DE JUSTIÃA  2024
# ...       ...  ...                                                ...   ...
# 3711      STJ  SUP                   GABINETE DO MINISTRO MARCO BUZZI  2024
# 3712      STJ  SUP  GABINETE DO MINISTRO HUMBERTO EUSTÃ?QUIO SOARE...  2024
# 3713      STJ  SUP       GABINETE DO MINISTRO SEBASTIÃO REIS JÃNIOR  2024
# 3714      STJ  SUP                                       PRESIDÃNCIA  2025
# 3715      STJ  SUP           GABINETE DO MINISTRO JOEL ILAN PACIORNIK  2024
#
#       Mes                   Processo  Codigo_da_Ultima_classe  \
# 0       1  0093715-28.2022.8.19.0000                    11881
# 1       1  1032460-20.2022.8.26.0562                    11881
# 2       8  0112785-32.2014.8.09.0051                    11881
# 3      12  0470194-63.2024.3.00.0000                     1720
# 4       8  0808892-65.2023.8.15.0000                    11881
# ...   ...                        ...                      ...
# 3711   11  0350114-60.2015.8.09.0051                    11881
# 3712   11  5220780-13.2022.8.21.7000                    11881
# 3713    3  0003631-55.2024.3.00.0000                     1720
# 3714    1  2336267-58.2023.8.26.0000                    11881
# 3715    2  1871401-69.2023.8.13.0000                     1722
#
#                     Nome_da_Ultima_classe Codigos_classes  \
# 0              AGRAVO EM RECURSO ESPECIAL         {11881}
# 1              AGRAVO EM RECURSO ESPECIAL         {11881}
# 2              AGRAVO EM RECURSO ESPECIAL         {11881}
# 3                           HABEAS CORPUS          {1720}
# 4              AGRAVO EM RECURSO ESPECIAL         {11881}
# ...                                   ...             ...
# 3711           AGRAVO EM RECURSO ESPECIAL         {11881}
# 3712           AGRAVO EM RECURSO ESPECIAL         {11881}
# 3713                        HABEAS CORPUS          {1720}
# 3714           AGRAVO EM RECURSO ESPECIAL         {11881}
# 3715  RECURSO ORDINÃ?RIO EM HABEAS CORPUS          {1722}
#
#                  Codigos_assuntos Data_de_Referencia      Formato  \
# 0     {9587,7779,9596,7780,11860}         2024-01-30  EletrÃ´nico
# 1                         {10240}         2025-01-29  EletrÃ´nico
# 2                          {4951}         2024-08-08  EletrÃ´nico
# 3                          {3372}         2024-12-10  EletrÃ´nico
# 4                   {10458,10939}         2024-08-19  EletrÃ´nico
# ...                           ...                ...          ...
# 3711                       {4960}         2024-11-11  EletrÃ´nico
# 3712                      {10439}         2024-11-04  EletrÃ´nico
# 3713                       {5566}         2024-03-01  EletrÃ´nico
# 3714                 {10945,8843}         2025-01-10  EletrÃ´nico
# 3715                  {3568,7929}         2024-02-01  EletrÃ´nico
#
#       Codigo_Orgao   Status Data_de_inicio Data_da_ultima_movimentacao  \
# 0            12728     Novo            NaN                         NaN
# 1            12728     Novo            NaN                         NaN
# 2            12728     Novo            NaN                         NaN
# 3            76789     Novo            NaN                         NaN
# 4            12728     Novo            NaN                         NaN
# ...            ...      ...            ...                         ...
# 3711         76762  Julgado            NaN                         NaN
# 3712         76755  Julgado            NaN                         NaN
# 3713         76777  Julgado            NaN                         NaN
# 3714         76789  Julgado            NaN                         NaN
# 3715         76757  Julgado            NaN                         NaN
#
#       Dias_de_antiguidade
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 3711                  NaN
# 3712                  NaN
# 3713                  NaN
# 3714                  NaN
# 3715                  NaN
#
# [3716 rows x 17 columns]

# %% [markdown]
# #**STM**

# %% [markdown]
# **Seleção de Dados**

# %%
STM_cn = '/content/STM_CN.csv'
STM_cpl = '/content/STM_CPL.csv'
STM_cpl15 = '/content/STM_CPL_15anos.csv'
STM_julg = '/content/STM_Sent.csv'
STM_baix = '/content/STM_TBaix.csv'


STM_cn = pd.read_csv(STM_cn, encoding='latin-1', sep=';', on_bad_lines='skip')
STM_cpl = pd.read_csv(STM_cpl, encoding='latin-1', sep=';', on_bad_lines='skip')
STM_cpl15 = pd.read_csv(STM_cpl15, encoding='latin-1', sep=';', on_bad_lines='skip')
STM_julg = pd.read_csv(STM_julg, encoding='latin-1', sep=';', on_bad_lines='skip')
STM_baix = pd.read_csv(STM_baix, encoding='latin-1', sep=';', on_bad_lines='skip')

# %%
STM_cn = STM_cn.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM1 = STM_cn.copy()
df_STM1['Status'] = 'Novo'

df_STM1.head(5)
# Out:
#   Tribunal Grau                                      Nome_Orgao   Ano  Mes  \
# 0      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    1
# 1      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    2
# 2      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    2
# 3      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    2
# 4      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    2
#
#                     Processo  Codigo_da_Ultima_classe  \
# 0  7000005-70.2024.7.00.0000                      426
# 1  7000040-30.2024.7.00.0000                      417
# 2  7000068-95.2024.7.00.0000                      417
# 3  7000076-72.2024.7.00.0000                      417
# 4  7000109-62.2024.7.00.0000                      417
#
#         Nome_da_Ultima_classe Codigos_classes          Codigos_assuntos  \
# 0  RECURSO EM SENTIDO ESTRITO           {426}             {11207,11103}
# 1         APELAÃÃO CRIMINAL           {417}       {10952,10641,11135}
# 2         APELAÃÃO CRIMINAL           {417}  {11090,10940,11207,8919}
# 3         APELAÃÃO CRIMINAL           {417}       {10952,11207,10523}
# 4         APELAÃÃO CRIMINAL           {417}             {11352,11353}
#
#   Data_de_Referencia      Formato  Codigo_Orgao Status
# 0         2024-01-10  EletrÃ´nico         32713   Novo
# 1         2024-02-02  EletrÃ´nico         32713   Novo
# 2         2024-02-14  EletrÃ´nico         32713   Novo
# 3         2024-02-15  EletrÃ´nico         32713   Novo
# 4         2024-02-27  EletrÃ´nico         32713   Novo

# %%
STM_cpl = STM_cpl.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM2 = STM_cpl.copy()
df_STM2['Status'] = 'Pendente'

df_STM2.head(5)
# Out:
#   Tribunal Grau                                         Nome_Orgao   Ano  Mes  \
# 0      STM  SUP  GABINETE DO MINISTRO LÃCIO MÃ?RIO DE BARROS G...  2025    1
# 1      STM  SUP     GABINETE DO MINISTRO CLEONILSON NICÃ?CIO SILVA  2025    1
# 2      STM  SUP  GABINETE DO MINISTRO MARCUS VINICIUS OLIVEIRA ...  2025    1
# 3      STM  SUP  GABINETE DO MINISTRO MARCUS VINICIUS OLIVEIRA ...  2025    1
# 4      STM  SUP  GABINETE DO MINISTRO MARCUS VINICIUS OLIVEIRA ...  2025    1
#
#                     Processo  Codigo_da_Ultima_classe  \
# 0  0000030-58.2004.7.01.0201                      417
# 1  0000043-22.2011.7.01.0101                      417
# 2  7000259-53.2018.7.00.0000                     1348
# 3  0000238-90.2014.7.01.0201                     1348
# 4  7000614-63.2018.7.00.0000                     1348
#
#      Nome_da_Ultima_classe Codigos_classes           Codigos_assuntos  \
# 0      APELAÃÃO CRIMINAL           {417}                    {11167}
# 1      APELAÃÃO CRIMINAL           {417}                    {11167}
# 2  RECURSO EXTRAORDINÃ?RIO          {1348}  {10641,11091,11167,11103}
# 3  RECURSO EXTRAORDINÃ?RIO          {1348}                    {11330}
# 4  RECURSO EXTRAORDINÃ?RIO          {1348}        {11327,11055,10867}
#
#   Data_de_inicio Data_da_ultima_movimentacao  Dias_de_antiguidade  \
# 0     2007-11-26                  2024-11-26                 6276
# 1     2017-09-28                  2024-04-30                 2682
# 2            NaN                  2019-10-08                 2494
# 3     2018-06-04                  2020-02-14                 2433
# 4     2018-07-31                  2021-03-10                 2376
#
#        Formato  Codigo_Orgao    Status
# 0  EletrÃ´nico         32720  Pendente
# 1  EletrÃ´nico         32717  Pendente
# 2  EletrÃ´nico         32718  Pendente
# 3  EletrÃ´nico         32718  Pendente
# 4  EletrÃ´nico         32718  Pendente

# %%
STM_cpl15 = STM_cpl15.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM3 = STM_cpl15.copy()
df_STM3['Status'] = 'Pendente +15'

df_STM3.head(5)
# Out:
#   Tribunal Grau                                         Nome_Orgao   Ano  Mes  \
# 0      STM  SUP  GABINETE DO MINISTRO LÃCIO MÃ?RIO DE BARROS G...  2025    1
#
#                     Processo  Codigo_da_Ultima_classe Nome_da_Ultima_classe  \
# 0  0000030-58.2004.7.01.0201                      417   APELAÃÃO CRIMINAL
#
#   Codigos_classes Codigos_assuntos Data_de_inicio Data_da_ultima_movimentacao  \
# 0           {417}          {11167}     2007-11-26                  2024-11-26
#
#    Dias_de_antiguidade      Formato  Codigo_Orgao        Status
# 0                 6276  EletrÃ´nico         32720  Pendente +15

# %%
STM_julg =STM_julg.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Data_da_decisao:_Situacao:_Movimento', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM4 = STM_julg.copy()
df_STM4['Status'] = 'Julgado'

df_STM4.head(5)
# Out:
#   Tribunal Grau                                      Nome_Orgao   Ano  Mes  \
# 0      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    3
# 1      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    4
# 2      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024   12
# 3      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    6
# 4      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    8
#
#                     Processo Codigos_classes  Codigo_da_Ultima_classe  \
# 0  7000005-70.2024.7.00.0000           {426}                      426
# 1  7000023-28.2023.7.00.0000           {417}                      417
# 2  7000040-30.2024.7.00.0000           {417}                      417
# 3  7000068-95.2024.7.00.0000           {417}                      417
# 4  7000076-72.2024.7.00.0000           {417}                      417
#
#         Nome_da_Ultima_classe           Codigos_assuntos Data_de_Referencia  \
# 0  RECURSO EM SENTIDO ESTRITO              {11207,11103}         2024-03-14
# 1         APELAÃÃO CRIMINAL  {10952,11163,10940,11071}         2024-04-04
# 2         APELAÃÃO CRIMINAL        {10952,10641,11135}         2024-12-05
# 3         APELAÃÃO CRIMINAL   {11090,10940,11207,8919}         2024-06-20
# 4         APELAÃÃO CRIMINAL        {10952,11207,10523}         2024-08-22
#
#        Formato  Codigo_Orgao   Status
# 0  EletrÃ´nico         32713  Julgado
# 1  EletrÃ´nico         32713  Julgado
# 2  EletrÃ´nico         32713  Julgado
# 3  EletrÃ´nico         32713  Julgado
# 4  EletrÃ´nico         32713  Julgado

# %%
STM_baix =STM_baix.drop(columns=['UF', 'Recurso_Originario', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_STM5 = STM_baix.copy()
df_STM5['Status'] = 'Baixado'

df_STM5.head(5)
# Out:
#   Tribunal Grau                                      Nome_orgao   Ano  Mes  \
# 0      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    4
# 1      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    4
# 2      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024   12
# 3      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    7
# 4      STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    9
#
#                     Processo  Codigo_da_Ultima_classe  \
# 0  7000005-70.2024.7.00.0000                      426
# 1  7000023-28.2023.7.00.0000                      417
# 2  7000040-30.2024.7.00.0000                      417
# 3  7000068-95.2024.7.00.0000                      417
# 4  7000076-72.2024.7.00.0000                      417
#
#         Nome_da_ultima_classe Codigos_Classes           Codigos_assuntos  \
# 0  RECURSO EM SENTIDO ESTRITO           {426}              {11207,11103}
# 1         APELAÃÃO CRIMINAL           {417}  {10952,11163,10940,11071}
# 2         APELAÃÃO CRIMINAL           {417}        {10952,10641,11135}
# 3         APELAÃÃO CRIMINAL           {417}   {11090,10940,11207,8919}
# 4         APELAÃÃO CRIMINAL           {417}        {10952,11207,10523}
#
#   Data_de_inicio Data_de_Referencia      Formato  Codigo_orgao   Status
# 0     2024-01-10         2024-04-09  EletrÃ´nico         32713  Baixado
# 1     2023-01-10         2024-04-15  EletrÃ´nico         32713  Baixado
# 2     2024-02-02         2024-12-21  EletrÃ´nico         32713  Baixado
# 3     2024-02-14         2024-07-01  EletrÃ´nico         32713  Baixado
# 4     2024-02-15         2024-09-12  EletrÃ´nico         32713  Baixado

# %%
df_STM = pd.concat([df_STM1, df_STM2, df_STM3, df_STM4, df_STM5], ignore_index=True)

df_STM['Ano'] = df_STM['Ano'].astype(int)
df_STM['Mes'] = df_STM['Mes'].astype(int)

display(df_STM)

df_STM.to_csv('STM.csv', index=False)
df_STM.to_excel('STM.xlsx', index=False)
# Out:
#      Tribunal Grau                                      Nome_Orgao   Ano  Mes  \
# 0         STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    1
# 1         STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    2
# 2         STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    2
# 3         STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    2
# 4         STM  SUP  GABINETE DO MINISTRO ARTUR VIDIGAL DE OLIVEIRA  2024    2
# ...       ...  ...                                             ...   ...  ...
# 2573      STM  SUP                                             NaN  2024    3
# 2574      STM  SUP                                             NaN  2024   10
# 2575      STM  SUP                                             NaN  2024    9
# 2576      STM  SUP                                             NaN  2024    8
# 2577      STM  SUP                                             NaN  2024   12
#
#                        Processo  Codigo_da_Ultima_classe  \
# 0     7000005-70.2024.7.00.0000                      426
# 1     7000040-30.2024.7.00.0000                      417
# 2     7000068-95.2024.7.00.0000                      417
# 3     7000076-72.2024.7.00.0000                      417
# 4     7000109-62.2024.7.00.0000                      417
# ...                         ...                      ...
# 2573        sigiloso(636231218)                      325
# 2574  7000097-82.2023.7.00.0000                    11034
# 2575  7000578-79.2022.7.00.0000                    11035
# 2576  7000818-34.2023.7.00.0000                    11035
# 2577        sigiloso(671711718)                    11035
#
#            Nome_da_Ultima_classe Codigos_classes  \
# 0     RECURSO EM SENTIDO ESTRITO           {426}
# 1            APELAÃÃO CRIMINAL           {417}
# 2            APELAÃÃO CRIMINAL           {417}
# 3            APELAÃÃO CRIMINAL           {417}
# 4            APELAÃÃO CRIMINAL           {417}
# ...                          ...             ...
# 2573                         NaN             NaN
# 2574                         NaN             NaN
# 2575                         NaN             NaN
# 2576                         NaN             NaN
# 2577                         NaN             NaN
#
#                   Codigos_assuntos  ...      Formato Codigo_Orgao   Status  \
# 0                    {11207,11103}  ...  EletrÃ´nico      32713.0     Novo
# 1              {10952,10641,11135}  ...  EletrÃ´nico      32713.0     Novo
# 2         {11090,10940,11207,8919}  ...  EletrÃ´nico      32713.0     Novo
# 3              {10952,11207,10523}  ...  EletrÃ´nico      32713.0     Novo
# 4                    {11352,11353}  ...  EletrÃ´nico      32713.0     Novo
# ...                            ...  ...          ...          ...      ...
# 2573                        {3642}  ...  EletrÃ´nico          NaN  Baixado
# 2574                 {11097,11094}  ...  EletrÃ´nico          NaN  Baixado
# 2575            {3637,11097,11094}  ...  EletrÃ´nico          NaN  Baixado
# 2576           {11097,11094,11167}  ...  EletrÃ´nico          NaN  Baixado
# 2577  {5560,11097,3402,3403,11094}  ...  EletrÃ´nico          NaN  Baixado
#
#      Data_de_inicio Data_da_ultima_movimentacao Dias_de_antiguidade  \
# 0               NaN                         NaN                 NaN
# 1               NaN                         NaN                 NaN
# 2               NaN                         NaN                 NaN
# 3               NaN                         NaN                 NaN
# 4               NaN                         NaN                 NaN
# ...             ...                         ...                 ...
# 2573     2023-10-18                         NaN                 NaN
# 2574     2023-02-09                         NaN                 NaN
# 2575     2022-08-25                         NaN                 NaN
# 2576     2023-10-04                         NaN                 NaN
# 2577     2024-04-05                         NaN                 NaN
#
#                                         Nome_orgao  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2573  GABINETE DO MINISTRO LOURIVAL CARVALHO SILVA
# 2574  GABINETE DO MINISTRO LOURIVAL CARVALHO SILVA
# 2575  GABINETE DO MINISTRO LOURIVAL CARVALHO SILVA
# 2576  GABINETE DO MINISTRO LOURIVAL CARVALHO SILVA
# 2577  GABINETE DO MINISTRO LOURIVAL CARVALHO SILVA
#
#                                   Nome_da_ultima_classe Codigos_Classes  \
# 0                                                   NaN             NaN
# 1                                                   NaN             NaN
# 2                                                   NaN             NaN
# 3                                                   NaN             NaN
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 2573                           CONFLITO DE JURISDIÃÃO           {325}
# 2574                         CONSELHO DE JUSTIFICAÃÃO         {11034}
# 2575  REPRESENTAÃÃO P/ DECLARAÃÃO DE INDIGNIDADE...         {11035}
# 2576  REPRESENTAÃÃO P/ DECLARAÃÃO DE INDIGNIDADE...         {11035}
# 2577  REPRESENTAÃÃO P/ DECLARAÃÃO DE INDIGNIDADE...         {11035}
#
#      Codigo_orgao
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 2573      84822.0
# 2574      84822.0
# 2575      84822.0
# 2576      84822.0
# 2577      84822.0
#
# [2578 rows x 21 columns]

# %% [markdown]
# #**TSE**

# %% [markdown]
# **Seleção de Dados**

# %%
TSE_cn = '/content/TSE_CN.csv'
TSE_cpl = '/content/TSE_CPL.csv'
TSE_cpl15 = '/content/TSE_CPL_15anos.csv'
TSE_julg = '/content/TSE_Sent.csv'
TSE_baix = '/content/TSE_TBaix.csv'


TSE_cn = pd.read_csv(TSE_cn, encoding='latin-1', sep=';', on_bad_lines='skip')
TSE_cpl = pd.read_csv(TSE_cpl, encoding='latin-1', sep=';', on_bad_lines='skip')
TSE_cpl15 = pd.read_csv(TSE_cpl15, encoding='latin-1', sep=';', on_bad_lines='skip')
TSE_julg = pd.read_csv(TSE_julg, encoding='latin-1', sep=';', on_bad_lines='skip')
TSE_baix = pd.read_csv(TSE_baix, encoding='latin-1', sep=';', on_bad_lines='skip')

# %%
TSE_cn = TSE_cn.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TSE_cn = TSE_cn.dropna()

df_TSE1 = TSE_cn.sample(n=1000, random_state=42).copy()
df_TSE1['Status'] = 'Novo'

df_TSE1.head(5)
# Out:
#       Tribunal Grau     Nome_Orgao   Ano  Mes                   Processo  \
# 3000       TSE  SUP  GABINETE STF1  2024    5  0607872-71.2024.6.00.0000
# 10290      TSE  SUP  GABINETE STF2  2024    9  0600192-45.2024.6.22.0025
# 736        TSE  SUP  GABINETE STF1  2024    5  0603647-08.2024.6.00.0000
# 8992       TSE  SUP  GABINETE STF1  2024    5  0612187-45.2024.6.00.0000
# 12795      TSE  SUP  GABINETE STJ1  2024    9  0600009-32.2024.6.14.0014
#
#        Codigo_da_Ultima_classe  \
# 3000                     12633
# 10290                    11549
# 736                      12631
# 8992                     12631
# 12795                    12626
#
#                                    Nome_da_Ultima_classe Codigos_classes  \
# 3000   REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...         {12633}
# 10290                         RECURSO ESPECIAL ELEITORAL         {11549}
# 736    REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...         {12631}
# 8992   REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...         {12631}
# 12795               AGRAVO EM RECURSO ESPECIAL ELEITORAL         {12626}
#
#       Codigos_assuntos Data_de_Referencia      Formato  Codigo_Orgao Status
# 3000           {12725}         2024-05-14  EletrÃ´nico         82599   Novo
# 10290    {11616,11638}         2024-09-23  EletrÃ´nico         82600   Novo
# 736            {12726}         2024-05-14  EletrÃ´nico         82599   Novo
# 8992           {12726}         2024-05-15  EletrÃ´nico         82599   Novo
# 12795          {12635}         2024-09-29  EletrÃ´nico         82602   Novo

# %%
TSE_cpl = TSE_cpl.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TSE_cpl = TSE_cpl.dropna()

df_TSE2 = TSE_cpl.sample(n=1000, random_state=42).copy()
df_TSE2['Status'] = 'Pendente'

df_TSE2.head(5)
# Out:
#      Tribunal Grau          Nome_Orgao   Ano  Mes                   Processo  \
# 2969      TSE  SUP       GABINETE STJ2  2025    1  0601466-27.2018.6.15.0000
# 2027      TSE  SUP       GABINETE STF2  2025    1  0600135-43.2021.6.10.0000
# 4046      TSE  SUP       GABINETE STJ1  2025    1  0600243-54.2024.6.02.0044
# 1223      TSE  SUP       GABINETE STF3  2025    1  0603862-08.2022.6.16.0000
# 1220      TSE  SUP  GABINETE JURISTA 1  2025    1  0600513-07.2023.6.00.0000
#
#       Codigo_da_Ultima_classe                 Nome_da_Ultima_classe  \
# 2969                    12626  AGRAVO EM RECURSO ESPECIAL ELEITORAL
# 2027                    11549            RECURSO ESPECIAL ELEITORAL
# 4046                    11549            RECURSO ESPECIAL ELEITORAL
# 1223                    11549            RECURSO ESPECIAL ELEITORAL
# 1220                    11551                              CONSULTA
#
#      Codigos_classes Codigos_assuntos Data_de_inicio  \
# 2969         {12626}          {11697}     2024-10-11
# 2027         {11549}          {12048}     2024-08-15
# 4046         {11549}          {11667}     2024-12-09
# 1223    {1321,11549}    {11705,11746}     2023-08-30
# 1220         {11551}          {12064}     2023-08-22
#
#      Data_da_ultima_movimentacao  Dias_de_antiguidade      Formato  \
# 2969                  2024-10-11                  112  EletrÃ´nico
# 2027                  2024-10-20                  169  EletrÃ´nico
# 4046                  2024-12-12                   53  EletrÃ´nico
# 1223                  2024-12-09                  520  EletrÃ´nico
# 1220                  2023-12-26                  528  EletrÃ´nico
#
#       Codigo_Orgao    Status
# 2969         82603  Pendente
# 2027         82600  Pendente
# 4046         82602  Pendente
# 1223         82601  Pendente
# 1220         82604  Pendente

# %%
TSE_cpl15 = TSE_cpl15.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_TSE3 = TSE_cpl15.copy()
df_TSE3['Status'] = 'Pendente +15'

df_TSE3.head(5)
# Out:
#   Tribunal Grau          Nome_Orgao   Ano  Mes                   Processo  \
# 0      TSE  SUP       GABINETE STF3  2025    1  0000005-83.1981.6.00.0000
# 1      TSE  SUP  GABINETE JURISTA 2  2025    1  0001658-95.1996.6.00.0000
# 2      TSE  SUP       GABINETE STF3  2025    1  0031774-98.2007.6.00.0000
# 3      TSE  SUP  GABINETE JURISTA 2  2025    1  0036159-55.2008.6.00.0000
# 4      TSE  SUP  GABINETE JURISTA 2  2025    1  0038585-40.2008.6.00.0000
#
#    Codigo_da_Ultima_classe                 Nome_da_Ultima_classe  \
# 0                    11539         REGISTRO DE PARTIDO POLÃ?TICO
# 1                    11539         REGISTRO DE PARTIDO POLÃ?TICO
# 2                    11549            RECURSO ESPECIAL ELEITORAL
# 3                    12626  AGRAVO EM RECURSO ESPECIAL ELEITORAL
# 4                    12626  AGRAVO EM RECURSO ESPECIAL ELEITORAL
#
#   Codigos_classes     Codigos_assuntos Data_de_inicio  \
# 0     {241,11539}              {12368}            NaN
# 1         {11539}              {12368}            NaN
# 2    {1321,11549}  {11697,11633,12046}     2007-08-31
# 3         {12626}  {11696,12046,11638}            NaN
# 4         {12626}              {12048}            NaN
#
#   Data_da_ultima_movimentacao  Dias_de_antiguidade      Formato  Codigo_Orgao  \
# 0                  2024-06-26                15971  EletrÃ´nico         82601
# 1                  2024-12-23                10332  EletrÃ´nico         82605
# 2                  2025-01-14                 6363  EletrÃ´nico         82601
# 3                  2024-09-28                 6033  EletrÃ´nico         82605
# 4                  2024-10-10                 5941  EletrÃ´nico         82605
#
#          Status
# 0  Pendente +15
# 1  Pendente +15
# 2  Pendente +15
# 3  Pendente +15
# 4  Pendente +15

# %%
TSE_julg = TSE_julg.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Data_da_decisao:_Situacao:_Movimento', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TSE_julg = TSE_julg.dropna()

df_TSE4 = TSE_julg.sample(n=1000, random_state=42).copy()
df_TSE4['Status'] = 'Julgados'

df_TSE4.head(5)
# Out:
#      Tribunal Grau          Nome_Orgao   Ano  Mes                   Processo  \
# 4615      TSE  SUP  GABINETE JURISTA 1  2024    2  0601430-38.2022.6.08.0000
# 5694      TSE  SUP  GABINETE JURISTA 2  2024    4  0000318-63.2016.6.08.0010
# 5542      TSE  SUP  GABINETE JURISTA 1  2024    2  0603631-78.2022.6.16.0000
# 435       TSE  SUP       GABINETE STF2  2024    3  0601924-11.2022.6.04.0000
# 1049      TSE  SUP       GABINETE STF2  2024   10  0601646-09.2022.6.22.0000
#
#      Codigos_classes  Codigo_da_Ultima_classe  \
# 4615         {11549}                    11549
# 5694    {12626,1321}                    12626
# 5542         {12626}                    12626
# 435     {12626,1321}                    12626
# 1049         {12626}                    12626
#
#                      Nome_da_Ultima_classe     Codigos_assuntos  \
# 4615            RECURSO ESPECIAL ELEITORAL  {11696,12046,11630}
# 5694  AGRAVO EM RECURSO ESPECIAL ELEITORAL  {12064,11501,11638}
# 5542  AGRAVO EM RECURSO ESPECIAL ELEITORAL  {11697,12046,11631}
# 435   AGRAVO EM RECURSO ESPECIAL ELEITORAL  {11697,12046,11630}
# 1049  AGRAVO EM RECURSO ESPECIAL ELEITORAL  {11696,12046,11631}
#
#      Data_de_Referencia      Formato  Codigo_Orgao    Status
# 4615         2024-02-16  EletrÃ´nico         82604  Julgados
# 5694         2024-04-14  EletrÃ´nico         82605  Julgados
# 5542         2024-02-16  EletrÃ´nico         82604  Julgados
# 435          2024-03-04  EletrÃ´nico         82600  Julgados
# 1049         2024-10-04  EletrÃ´nico         82600  Julgados

# %%
TSE_baix = TSE_baix.drop(columns=['UF', 'Recurso_Originario', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TSE_baix = TSE_baix.dropna()

df_TSE5 = TSE_baix.sample(n=600, random_state=42).copy()
df_TSE5['Status'] = 'Baixado'

df_TSE5.head(5)
# Out:
#       Tribunal Grau          Nome_orgao   Ano  Mes                   Processo  \
# 14165      TSE  SUP  GABINETE JURISTA 1  2024    9  0602373-06.2022.6.17.0000
# 11966      TSE  SUP       GABINETE STJ1  2024   11  0600222-27.2024.6.16.0032
# 3485       TSE  SUP       GABINETE STF1  2024    6  0608162-86.2024.6.00.0000
# 5733       TSE  SUP       GABINETE STF1  2024    6  0608628-80.2024.6.00.0000
# 13493      TSE  SUP  GABINETE JURISTA 1  2024    4  0601223-55.2022.6.11.0000
#
#        Codigo_da_Ultima_classe  \
# 14165                    12626
# 11966                    11549
# 3485                     12633
# 5733                     12633
# 13493                      202
#
#                                    Nome_da_ultima_classe Codigos_Classes  \
# 14165               AGRAVO EM RECURSO ESPECIAL ELEITORAL         {12626}
# 11966                         RECURSO ESPECIAL ELEITORAL         {11549}
# 3485   REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...         {12633}
# 5733   REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...         {12633}
# 13493                              AGRAVO DE INSTRUMENTO           {202}
#
#                 Codigos_assuntos Data_de_inicio Data_de_Referencia  \
# 14165        {11697,12046,11630}     2024-08-07         2024-09-19
# 11966  {11616,12044,11646,11638}     2024-10-11         2024-11-29
# 3485                     {12725}     2024-05-14         2024-06-20
# 5733                     {12725}     2024-05-14         2024-06-19
# 13493        {11697,12046,11630}     2024-01-25         2024-04-11
#
#            Formato  Codigo_orgao   Status
# 14165  EletrÃ´nico         82604  Baixado
# 11966  EletrÃ´nico         82602  Baixado
# 3485   EletrÃ´nico         82599  Baixado
# 5733   EletrÃ´nico         82599  Baixado
# 13493  EletrÃ´nico         82604  Baixado

# %%
df_TSE = pd.concat([df_TSE1, df_TSE2, df_TSE3, df_TSE4, df_TSE5], ignore_index=True)

df_TSE['Ano'] = df_TSE['Ano'].astype(int)
df_TSE['Mes'] = df_TSE['Mes'].astype(int)

display(df_TSE)

df_TSE.to_csv('TSE.csv', index=False)
df_TSE.to_excel('TSE.xlsx', index=False)
# Out:
#      Tribunal Grau     Nome_Orgao   Ano  Mes                   Processo  \
# 0         TSE  SUP  GABINETE STF1  2024    5  0607872-71.2024.6.00.0000
# 1         TSE  SUP  GABINETE STF2  2024    9  0600192-45.2024.6.22.0025
# 2         TSE  SUP  GABINETE STF1  2024    5  0603647-08.2024.6.00.0000
# 3         TSE  SUP  GABINETE STF1  2024    5  0612187-45.2024.6.00.0000
# 4         TSE  SUP  GABINETE STJ1  2024    9  0600009-32.2024.6.14.0014
# ...       ...  ...            ...   ...  ...                        ...
# 3607      TSE  SUP            NaN  2024    6  0612444-70.2024.6.00.0000
# 3608      TSE  SUP            NaN  2024    4  0602056-68.2022.6.04.0000
# 3609      TSE  SUP            NaN  2024    6  0607008-33.2024.6.00.0000
# 3610      TSE  SUP            NaN  2024    6  0609180-45.2024.6.00.0000
# 3611      TSE  SUP            NaN  2024    6  0602521-39.2022.6.09.0000
#
#       Codigo_da_Ultima_classe  \
# 0                       12633
# 1                       11549
# 2                       12631
# 3                       12631
# 4                       12626
# ...                       ...
# 3607                    12631
# 3608                    11549
# 3609                    12631
# 3610                    12633
# 3611                    12626
#
#                                   Nome_da_Ultima_classe Codigos_classes  \
# 0     REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...         {12633}
# 1                            RECURSO ESPECIAL ELEITORAL         {11549}
# 2     REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...         {12631}
# 3     REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...         {12631}
# 4                  AGRAVO EM RECURSO ESPECIAL ELEITORAL         {12626}
# ...                                                 ...             ...
# 3607                                                NaN             NaN
# 3608                                                NaN             NaN
# 3609                                                NaN             NaN
# 3610                                                NaN             NaN
# 3611                                                NaN             NaN
#
#          Codigos_assuntos  ...      Formato Codigo_Orgao   Status  \
# 0                 {12725}  ...  EletrÃ´nico      82599.0     Novo
# 1           {11616,11638}  ...  EletrÃ´nico      82600.0     Novo
# 2                 {12726}  ...  EletrÃ´nico      82599.0     Novo
# 3                 {12726}  ...  EletrÃ´nico      82599.0     Novo
# 4                 {12635}  ...  EletrÃ´nico      82602.0     Novo
# ...                   ...  ...          ...          ...      ...
# 3607              {12726}  ...  EletrÃ´nico          NaN  Baixado
# 3608  {11697,12046,11630}  ...  EletrÃ´nico          NaN  Baixado
# 3609              {12726}  ...  EletrÃ´nico          NaN  Baixado
# 3610              {12725}  ...  EletrÃ´nico          NaN  Baixado
# 3611  {11696,12046,11630}  ...  EletrÃ´nico          NaN  Baixado
#
#      Data_de_inicio Data_da_ultima_movimentacao Dias_de_antiguidade  \
# 0               NaN                         NaN                 NaN
# 1               NaN                         NaN                 NaN
# 2               NaN                         NaN                 NaN
# 3               NaN                         NaN                 NaN
# 4               NaN                         NaN                 NaN
# ...             ...                         ...                 ...
# 3607     2024-05-15                         NaN                 NaN
# 3608     2023-07-27                         NaN                 NaN
# 3609     2024-05-14                         NaN                 NaN
# 3610     2024-05-14                         NaN                 NaN
# 3611     2024-04-09                         NaN                 NaN
#
#          Nome_orgao                              Nome_da_ultima_classe  \
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 3607  GABINETE STF1  REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...
# 3608  GABINETE STF2                         RECURSO ESPECIAL ELEITORAL
# 3609  GABINETE STF1  REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...
# 3610  GABINETE STF1  REQUERIMENTO DE REGULARIZAÃÃO DE OMISSÃO DE...
# 3611  GABINETE STF3               AGRAVO EM RECURSO ESPECIAL ELEITORAL
#
#      Codigos_Classes Codigo_orgao
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# ...              ...          ...
# 3607         {12631}      82599.0
# 3608         {11549}      82600.0
# 3609         {12631}      82599.0
# 3610         {12633}      82599.0
# 3611         {12626}      82601.0
#
# [3612 rows x 21 columns]

# %% [markdown]
# #**TST**

# %% [markdown]
# **Seleção de Dados**

# %%
TST_cn = '/content/TST_CN.csv'
TST_cpl = '/content/TST_CPL.csv'
TST_cpl15 = '/content/TST_CPL_15anos.csv'
TST_julg = '/content/TST_Sent.csv'
TST_baix = '/content/TST_TBaix.csv'


TST_cn = pd.read_csv(TST_cn, encoding='latin-1', sep=';', on_bad_lines='skip')
TST_cpl = pd.read_csv(TST_cpl, encoding='latin-1', sep=';', on_bad_lines='skip')
TST_cpl15 = pd.read_csv(TST_cpl15, encoding='latin-1', sep=';', on_bad_lines='skip')
TST_julg = pd.read_csv(TST_julg, encoding='latin-1', sep=';', on_bad_lines='skip')
TST_baix = pd.read_csv(TST_baix, encoding='latin-1', sep=';', on_bad_lines='skip')

# %%
TST_cn = TST_cn.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TST_cn = TST_cn.dropna()

df_TST1 = TST_cn.sample(n=1000, random_state=42).copy()
df_TST1['Status'] = 'Novo'

df_TST1.head(5)
# Out:
#        Tribunal Grau                                         Nome_Orgao   Ano  \
# 347986      TST  SUP    GABINETE DO MINISTRO LUIZ JOSÃ DEZENA DA SILVA  2024
# 339913      TST  SUP       GABINETE DO MINISTRO HUGO CARLOS SCHEUERMANN  2024
# 190316      TST  SUP  GABINETE DO MINISTRO EVANDRO PEREIRA VALADÃO ...  2024
# 215875      TST  SUP                      TRIBUNAL SUPERIOR DO TRABALHO  2025
# 52109       TST  SUP                      TRIBUNAL SUPERIOR DO TRABALHO  2024
#
#         Mes                   Processo  Codigo_da_Ultima_classe  \
# 347986    4  1000996-61.2022.5.02.0605                     1002
# 339913    5  1001274-17.2021.5.02.0017                    11882
# 190316    5  0000359-90.2020.5.09.0965                    11882
# 215875    1  0010106-27.2024.5.03.0113                    11882
# 52109     2        sigiloso(605340083)                     1689
#
#                               Nome_da_Ultima_classe   Codigos_classes  \
# 347986  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA            {1002}
# 339913                RECURSO DE REVISTA COM AGRAVO           {11882}
# 190316                RECURSO DE REVISTA COM AGRAVO           {11882}
# 215875                RECURSO DE REVISTA COM AGRAVO           {11882}
# 52109               EMBARGOS DE DECLARAÃÃO CÃ?VEL  {1689,1002,1006}
#
#                                          Codigos_assuntos Data_de_Referencia  \
# 347986  {13184,13776,13922,14018,13875,13895,13769,137...         2024-04-29
# 339913   {13778,13780,13876,13976,9098,13962,13628,14012}         2024-05-14
# 190316  {13888,13765,13190,13767,13863,13864,13769,884...         2024-05-17
# 215875                                            {13722}         2025-01-24
# 52109   {13863,13864,13992,13769,14000,13745,13970,138...         2024-02-23
#
#             Formato  Codigo_Orgao Status
# 347986  EletrÃ´nico         79538   Novo
# 339913  EletrÃ´nico         45216   Novo
# 190316  EletrÃ´nico         80846   Novo
# 215875  EletrÃ´nico         13221   Novo
# 52109   EletrÃ´nico         13221   Novo

# %%
TST_cpl = TST_cpl.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TST_cpl = TST_cpl.dropna()

df_TST2 = TST_cpl.sample(n=1000, random_state=42).copy()
df_TST2['Status'] = 'Pendente'

df_TST2.head(5)
# Out:
#        Tribunal Grau                                     Nome_Orgao   Ano  \
# 582636      TST  SUP                                   PRESIDÃNCIA  2025
# 510945      TST  SUP                  TRIBUNAL SUPERIOR DO TRABALHO  2025
# 87706       TST  SUP  GABINETE DA MINISTRA KÃ?TIA MAGALHÃES ARRUDA  2025
# 158225      TST  SUP       GABINETE DA MINISTRA DORA MARIA DA COSTA  2025
# 591859      TST  SUP                                   PRESIDÃNCIA  2025
#
#         Mes                   Processo  Codigo_da_Ultima_classe  \
# 582636    1  0000829-82.2023.5.09.0653                     1002
# 510945    1  0001313-84.2023.5.12.0016                     1002
# 87706     1  0076100-08.2007.5.02.0054                     1002
# 158225    1  1001317-08.2020.5.02.0463                     1002
# 591859    1  1000220-98.2022.5.02.0431                     1002
#
#                               Nome_da_Ultima_classe        Codigos_classes  \
# 582636  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA                 {1002}
# 510945  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA                 {1002}
# 87706   AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA  {1008,1000,1689,1002}
# 158225  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA                 {1002}
# 591859  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA                 {1002}
#
#                                          Codigos_assuntos Data_de_inicio  \
# 582636  {13843,13875,13719,13432,13481,14010,13995,106...     2025-01-30
# 510945                    {11848,14000,13481,13875,13692}     2024-09-13
# 87706                            {14040,13233,14036,9149}     2022-03-28
# 158225  {13993,13962,13994,13420,14001,14033,13970,130...     2022-12-07
# 591859              {13769,13793,14018,13772,13796,13815}     2024-03-08
#
#        Data_da_ultima_movimentacao  Dias_de_antiguidade      Formato  \
# 582636                  2025-01-30                  1.0  EletrÃ´nico
# 510945                  2024-10-17                140.0  EletrÃ´nico
# 87706                   2024-12-17               4250.0  EletrÃ´nico
# 158225                  2024-10-15                786.0  EletrÃ´nico
# 591859                  2024-08-19                329.0  EletrÃ´nico
#
#         Codigo_Orgao    Status
# 582636         45227  Pendente
# 510945         13221  Pendente
# 87706          45185  Pendente
# 158225         45184  Pendente
# 591859         45227  Pendente

# %%
TST_cpl15 = TST_cpl15.drop(columns=['Inicio_da_ultima_conclusao', 'Data_de_ajuizamento', 'Data_do_primeiro_julgamento', 'Data_do_julgamento:_Situacao:_Movimento', 'Data_da_decisao:_Situacao:_Movimento', 'Tipo_de_conclusao', 'Datas_inicio:fim', 'Liquido','Recurso_Originario', 'UF', 'Municipio', 'Recurso', 'Mais_15_anos', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

df_TST3 = TST_cpl15.copy()
df_TST3['Status'] = 'Pendente +15'

df_TST3.head(5)
# Out:
#   Tribunal Grau                                         Nome_Orgao   Ano  Mes  \
# 0      TST  SUP  GABINETE DO MINISTRO GUILHERME AUGUSTO CAPUTO ...  2025    1
# 1      TST  SUP       GABINETE DO MINISTRO HUGO CARLOS SCHEUERMANN  2025    1
# 2      TST  SUP      GABINETE DA MINISTRA KÃ?TIA MAGALHÃES ARRUDA  2025    1
# 3      TST  SUP  GABINETE DO MINISTRO EVANDRO PEREIRA VALADÃO ...  2025    1
# 4      TST  SUP  GABINETE DO MINISTRO EVANDRO PEREIRA VALADÃO ...  2025    1
#
#                     Processo  Codigo_da_Ultima_classe Nome_da_Ultima_classe  \
# 0  0467048-43.1998.5.12.5555                     1008    RECURSO DE REVISTA
# 1  2855600-94.2002.5.06.0900                      241      PETIÃÃO CÃ?VEL
# 2  7523900-65.2003.5.02.0900                     1008    RECURSO DE REVISTA
# 3  9793300-78.2003.5.01.0900                     1000                AGRAVO
# 4  0131440-82.2001.5.24.0005                     1008    RECURSO DE REVISTA
#
#                   Codigos_classes           Codigos_assuntos Data_de_inicio  \
# 0                          {1008}                      {864}     2012-08-13
# 1                 {241,1689,1002}  {10685,13038,13982,13623}     2002-05-02
# 2  {1008,241,1000,1689,1002,1006}                    {14043}     2003-01-23
# 3       {1008,241,1000,1689,1006}              {13954,13003}     2003-09-04
# 4                {1008,1689,1002}        {14040,13062,13559}     2003-10-30
#
#   Data_da_ultima_movimentacao  Dias_de_antiguidade      Formato  Codigo_Orgao  \
# 0                  2019-11-25                 9711      FÃ­sico         45215
# 1                  2020-06-02                 8310  EletrÃ´nico         45216
# 2                  2021-05-24                 8044  EletrÃ´nico         45185
# 3                  2024-08-23                 7820  EletrÃ´nico         80846
# 4                  2024-06-25                 7764  EletrÃ´nico         80846
#
#          Status
# 0  Pendente +15
# 1  Pendente +15
# 2  Pendente +15
# 3  Pendente +15
# 4  Pendente +15

# %%
TST_julg = TST_julg.drop(columns=['UF', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Data_da_decisao:_Situacao:_Movimento', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])
TST_julg = TST_julg.dropna()

df_TST4 = TST_julg.sample(n=1000, random_state=42).copy()
df_TST4['Status'] = 'Julgado'

df_TST4.head(5)
# Out:
#        Tribunal Grau                                         Nome_Orgao   Ano  \
# 60800       TST  SUP          GABINETE DO MINISTRO SERGIO PINTO MARTINS  2024
# 361289      TST  SUP  GABINETE DO DESEMBARGADOR CONVOCADO JOSÃ PEDR...  2024
# 385399      TST  SUP  GABINETE DO MINISTRO CLÃ?UDIO MASCARENHAS BRAN...  2024
# 307844      TST  SUP      GABINETE DA MINISTRA KÃ?TIA MAGALHÃES ARRUDA  2024
# 168361      TST  SUP      GABINETE DA MINISTRA KÃ?TIA MAGALHÃES ARRUDA  2024
#
#         Mes                   Processo   Codigos_classes  \
# 60800     4  0000438-52.2022.5.17.0003       {1000,1002}
# 361289    9  0010503-12.2023.5.18.0111            {1002}
# 385399    5  0100756-48.2022.5.01.0501            {1002}
# 307844   10  0000519-68.2017.5.12.0050  {1000,1689,1002}
# 168361    6  0010741-96.2021.5.15.0139       {1000,1002}
#
#         Codigo_da_Ultima_classe                        Nome_da_Ultima_classe  \
# 60800                      1002  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA
# 361289                     1002  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA
# 385399                     1002  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA
# 307844                     1002  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA
# 168361                     1002  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA
#
#                                  Codigos_assuntos Data_de_Referencia  \
# 60800                                     {13974}         2024-04-08
# 361289                                    {13924}         2024-09-10
# 385399                                    {13970}         2024-05-27
# 307844            {13776,14010,13772,13877,14030}         2024-10-16
# 168361  {13875,13831,13863,2663,10685,13853,2479}         2024-06-27
#
#             Formato  Codigo_Orgao   Status
# 60800   EletrÃ´nico         84522  Julgado
# 361289  EletrÃ´nico         85726  Julgado
# 385399  EletrÃ´nico         45211  Julgado
# 307844  EletrÃ´nico         45185  Julgado
# 168361  EletrÃ´nico         45185  Julgado

# %%
TST_baix = TST_baix.drop(columns=['UF', 'Recurso_Originario', 'Municipio', 'Recurso', 'Procedimento', 'id_municipio', 'Polo_passivo', 'Polo_ativo', 'Polo_ativo_-_CNPJ', 'Polo_ativo_-_Natureza_juridica', 'Polo_ativo_-_CNAE', 'Polo_ativo_-_Natureza_juridica', 'Polo_passivo_-_CNPJ', 'Polo_passivo_-_Natureza_juridica', 'Polo_passivo_-_CNAE', 'Poder_publico'])

TST_baix = TST_baix.dropna()

df_TST5 = TST_baix.sample(n=600, random_state=42).copy()
df_TST5['Status'] = 'Baixado'

df_TST5.head(5)
# Out:
#        Tribunal Grau                                         Nome_orgao   Ano  \
# 227566      TST  SUP                      TRIBUNAL SUPERIOR DO TRABALHO  2024
# 194118      TST  SUP      GABINETE DA MINISTRA MORGANA DE ALMEIDA RICHA  2024
# 155580      TST  SUP                                       PRESIDÃNCIA  2024
# 185734      TST  SUP  GABINETE DO MINISTRO JOSÃ ROBERTO FREIRE PIMENTA  2024
# 144321      TST  SUP                                       PRESIDÃNCIA  2024
#
#         Mes                   Processo  Codigo_da_Ultima_classe  \
# 227566   10  0000877-78.2017.5.12.0035                     1008
# 194118    4  0100742-36.2017.5.01.0082                    11882
# 155580    6  0021436-28.2014.5.04.0021                     1008
# 185734    2  0001865-07.2017.5.05.0161                    11882
# 144321    4  0000977-19.2013.5.03.0069                     1002
#
#                               Nome_da_ultima_classe Codigos_Classes  \
# 227566                           RECURSO DE REVISTA          {1008}
# 194118                RECURSO DE REVISTA COM AGRAVO         {11882}
# 155580                           RECURSO DE REVISTA     {1008,1689}
# 185734                RECURSO DE REVISTA COM AGRAVO    {1000,11882}
# 144321  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA          {1002}
#
#                        Codigos_assuntos Data_de_inicio Data_de_Referencia  \
# 227566                          {13526}     2024-07-23         2024-10-02
# 194118  {13922,13748,10685,13405,13831}     2021-07-28         2024-04-18
# 155580                    {13184,13782}     2019-04-25         2024-06-14
# 185734         {13233,8843,13771,13844}     2021-08-13         2024-02-19
# 144321                    {13776,13769}     2014-03-26         2024-04-08
#
#             Formato  Codigo_orgao   Status
# 227566  EletrÃ´nico         13221  Baixado
# 194118  EletrÃ´nico         84137  Baixado
# 155580  EletrÃ´nico         45227  Baixado
# 185734  EletrÃ´nico         45220  Baixado
# 144321  EletrÃ´nico         45227  Baixado

# %%
df_TST = pd.concat([df_TST1, df_TST2, df_TST3, df_TST4, df_TST5], ignore_index=True)

df_TST['Ano'] = df_TST['Ano'].astype(int)
df_TST['Mes'] = df_TST['Mes'].astype(int)

display(df_TST)

df_TST.to_csv('TST.csv', index=False)
df_TST.to_excel('TST.xlsx', index=False)
# Out:
#      Tribunal Grau                                         Nome_Orgao   Ano  \
# 0         TST  SUP    GABINETE DO MINISTRO LUIZ JOSÃ DEZENA DA SILVA  2024
# 1         TST  SUP       GABINETE DO MINISTRO HUGO CARLOS SCHEUERMANN  2024
# 2         TST  SUP  GABINETE DO MINISTRO EVANDRO PEREIRA VALADÃO ...  2024
# 3         TST  SUP                      TRIBUNAL SUPERIOR DO TRABALHO  2025
# 4         TST  SUP                      TRIBUNAL SUPERIOR DO TRABALHO  2024
# ...       ...  ...                                                ...   ...
# 6717      TST  SUP                                                NaN  2024
# 6718      TST  SUP                                                NaN  2024
# 6719      TST  SUP                                                NaN  2024
# 6720      TST  SUP                                                NaN  2024
# 6721      TST  SUP                                                NaN  2024
#
#       Mes                   Processo  Codigo_da_Ultima_classe  \
# 0       4  1000996-61.2022.5.02.0605                     1002
# 1       5  1001274-17.2021.5.02.0017                    11882
# 2       5  0000359-90.2020.5.09.0965                    11882
# 3       1  0010106-27.2024.5.03.0113                    11882
# 4       2        sigiloso(605340083)                     1689
# ...   ...                        ...                      ...
# 6717    2  1001359-16.2019.5.02.0003                    11882
# 6718    4  0010854-55.2021.5.15.0105                     1002
# 6719    3  1001651-46.2017.5.02.0431                     1002
# 6720    1  0102600-69.2001.5.03.0030                    11882
# 6721   10  1000769-44.2022.5.02.0323                     1002
#
#                             Nome_da_Ultima_classe   Codigos_classes  \
# 0     AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA            {1002}
# 1                   RECURSO DE REVISTA COM AGRAVO           {11882}
# 2                   RECURSO DE REVISTA COM AGRAVO           {11882}
# 3                   RECURSO DE REVISTA COM AGRAVO           {11882}
# 4                 EMBARGOS DE DECLARAÃÃO CÃ?VEL  {1689,1002,1006}
# ...                                           ...               ...
# 6717                                          NaN               NaN
# 6718                                          NaN               NaN
# 6719                                          NaN               NaN
# 6720                                          NaN               NaN
# 6721                                          NaN               NaN
#
#                                        Codigos_assuntos  ...      Formato  \
# 0     {13184,13776,13922,14018,13875,13895,13769,137...  ...  EletrÃ´nico
# 1      {13778,13780,13876,13976,9098,13962,13628,14012}  ...  EletrÃ´nico
# 2     {13888,13765,13190,13767,13863,13864,13769,884...  ...  EletrÃ´nico
# 3                                               {13722}  ...  EletrÃ´nico
# 4     {13863,13864,13992,13769,14000,13745,13970,138...  ...  EletrÃ´nico
# ...                                                 ...  ...          ...
# 6717                                {13420,14076,10655}  ...  EletrÃ´nico
# 6718                                       {9098,14075}  ...  EletrÃ´nico
# 6719  {13778,13620,13732,13799,13895,14040,13481,137...  ...  EletrÃ´nico
# 6720                                       {9178,13094}  ...  EletrÃ´nico
# 6721               {13048,13184,13481,13850,4435,13931}  ...  EletrÃ´nico
#
#      Codigo_Orgao   Status Data_de_inicio Data_da_ultima_movimentacao  \
# 0         79538.0     Novo            NaN                         NaN
# 1         45216.0     Novo            NaN                         NaN
# 2         80846.0     Novo            NaN                         NaN
# 3         13221.0     Novo            NaN                         NaN
# 4         13221.0     Novo            NaN                         NaN
# ...           ...      ...            ...                         ...
# 6717          NaN  Baixado     2020-10-07                         NaN
# 6718          NaN  Baixado     2023-09-22                         NaN
# 6719          NaN  Baixado     2023-12-12                         NaN
# 6720          NaN  Baixado     2023-08-04                         NaN
# 6721          NaN  Baixado     2024-06-28                         NaN
#
#      Dias_de_antiguidade                                         Nome_orgao  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 6717                 NaN          GABINETE DO MINISTRO SERGIO PINTO MARTINS
# 6718                 NaN  GABINETE DO MINISTRO AUGUSTO CÃSAR LEITE DE C...
# 6719                 NaN                                       PRESIDÃNCIA
# 6720                 NaN  GABINETE DA MINISTRA MARIA CRISTINA IRIGOYEN P...
# 6721                 NaN                      TRIBUNAL SUPERIOR DO TRABALHO
#
#                             Nome_da_ultima_classe Codigos_Classes Codigo_orgao
# 0                                             NaN             NaN          NaN
# 1                                             NaN             NaN          NaN
# 2                                             NaN             NaN          NaN
# 3                                             NaN             NaN          NaN
# 4                                             NaN             NaN          NaN
# ...                                           ...             ...          ...
# 6717                RECURSO DE REVISTA COM AGRAVO         {11882}      84522.0
# 6718  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA          {1002}      45210.0
# 6719  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA          {1002}      45227.0
# 6720                RECURSO DE REVISTA COM AGRAVO    {1002,11882}      45186.0
# 6721  AGRAVO DE INSTRUMENTO EM RECURSO DE REVISTA          {1002}      13221.0
#
# [6722 rows x 21 columns]
